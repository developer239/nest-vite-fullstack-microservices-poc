# %% [markdown]
# ## RabbitMQ Docker Image

# %%
region = "us-central1"
project_id = "nest-vite-fs-microservices"
env = "dev"

# %%
# Build the Docker image
# !docker build -t {region}-docker.pkg.dev/{project_id}/{project_id}-{env}-repo/{env}-rabbitmq:latest -f Dockerfile .
# Out:
# [+] Building 0.0s (0/0)  docker:desktop-linux
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.2s (2/3)                                    docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 113B                                       0.0s
#  => [internal] load metadata for docker.io/library/rabbitmq:3-management-  0.2s
# [+] Building 0.3s (2/3)                                    docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
# ...

# %%
# Push the image to Artifact Registry
# !docker push {region}-docker.pkg.dev/{project_id}/{project_id}-{env}-repo/{env}-rabbitmq:latest
# Out:
# The push refers to repository [us-central1-docker.pkg.dev/nest-vite-fs-microservices/nest-vite-fs-microservices-dev-repo/dev-rabbitmq]
#
# de8783a9: Preparing
# 32888db9: Preparing
# df56d255: Preparing
# 3d9c1c5a: Preparing
# 9861c0c4: Preparing
# cddcc4dd: Preparing
# 5efa2df5: Preparing
# b3014f45: Preparing
# b4bcaad1: Preparing
# b4bcaad1: Pushed   77.97MB/77.26MBlatest: digest: sha256:002537968bd6a95fbf2638f9032dd59458bd07b8923b9e07a0c0e7b4d95fe2db size: 2414
