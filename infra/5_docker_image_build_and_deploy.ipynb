# %% [markdown]
# # Docker Image Build & Deploy

# %% [markdown]
# Initialize local variables from the shared project variables file.

# %%
from project_vars import project_variables

env = project_variables['environment']
project_id = project_variables['project_id']
project_name = project_variables['project_name']
region = project_variables['region']

# %% [markdown]
# This notebook is often used standalone to build and deploy a docker image. So we want to authenticate to GCP again. **If your session is authenticated you can skip this step.**

# %%
# !gcloud auth login
# Out:
# Your browser has been opened to visit:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8085%2F&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=E6UoAqelFsT32pzuyuuj42Zn5gbjHK&access_type=offline&code_challenge=7lu34ITjVfW0cl2IVRfrtMV3NRICDVCyb10RRzcsqbc&code_challenge_method=S256
#
#
# You are now logged in as [m.jarnot@yahoo.com].
# Your current project is [fs-microservices].  You can change this setting by running:
#   $ gcloud config set project PROJECT_ID

# %%
# !gcloud config set project {project_id}
# Out:
# Updated property [core/project].

# %% [markdown]
# Configure GCP to use Docker.

# %%
# !gcloud auth configure-docker
# Out:
# WARNING: Your config file at [/Users/michaljarnot/.docker/config.json] contains these credential helper entries:
#
# {
#   "credHelpers": {
#     "asia.gcr.io": "gcloud",
#     "eu.gcr.io": "gcloud",
#     "gcr.io": "gcloud",
#     "marketplace.gcr.io": "gcloud",
#     "staging-k8s.gcr.io": "gcloud",
#     "us-central1-docker.pkg.dev": "gcloud",
#     "us.gcr.io": "gcloud"
#   }
# }
# Adding credentials for all GCR repositories.
# WARNING: A long list of credential helpers may cause delays running 'docker build'. We recommend passing the registry name to configure only the registry you are using.
# gcloud credential helpers already registered correctly.

# %% [markdown]
# ## Service Build & Deploy

# %% [markdown]
# You need to build and deploy as many docker images as you have services. You also need to update services array when services change in `project_vars.py` file. The following code block generates select field that you can use to choose what service you want to deploy.

# %%
import ipywidgets as widgets
from IPython.display import display

services = [
    {"name": "auth-service", "folder": "service-auth"},
    {"name": "events-service", "folder": "service-events"},
    {"name": "gateway-service", "folder": "service-gateway"},
    {"name": "storybook-service", "folder": "storybook"},
    {"name": "web-service", "folder": "web"}
]

# Create a dropdown widget
dropdown = widgets.Dropdown(
    options=[(f"{s['name']} ({s['folder']})", s) for s in services],
    description='Select a service:',
    style={'description_width': 'initial'}
)

# Create output widgets to display the selected values
output_name = widgets.HTML()
output_folder = widgets.HTML()

def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        selected = change['new']
        global service_name, service_folder
        service_name = selected['name']
        service_folder = selected['folder']
        output_name.value = f"<b>service_name</b> = \"{service_name}\""
        output_folder.value = f"<b>service_folder</b> = \"{service_folder}\""

# Attach the callback to the dropdown
dropdown.observe(on_change, names='value')

# Display the widgets
display(dropdown, output_name, output_folder)
# Out:
# Dropdown(description='Select a service:', options=(('auth-service (service-auth)', {'name': 'auth-service', 'f…
# HTML(value='')
# HTML(value='')

# %% [markdown]
# Build the Docker image using the Dockerfile located in the parent directory.

# %%
# !docker build --no-cache -t {region}-docker.pkg.dev/{project_id}/{env}-repo/{env}-{service_name}:latest -f ../apps/{service_folder}/Dockerfile ../
# Out:
# [+] Building 0.0s (0/0)  docker:desktop-linux
# [+] Building 0.0s (0/1)                                    docker:desktop-linux
# [+] Building 0.1s (2/5)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            0.1s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.1s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
# [+] Building 0.3s (3/5)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            0.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.3s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
# [+] Building 0.4s (3/6)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            0.4s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.4s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
# [+] Building 0.6s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            0.5s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.5s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
# [+] Building 0.7s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            0.7s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.7s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
# [+] Building 0.9s (4/6)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            0.8s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.8s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
# [+] Building 0.9s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            0.9s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
# [+] Building 1.1s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.1s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
# [+] Building 1.2s (5/6)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.2s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
# [+] Building 1.4s (6/6)                                    docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
# [+] Building 1.5s (9/22)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 311.74kB                                      0.1s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
# [+] Building 1.6s (9/22)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 857.15kB                                      0.2s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
# [+] Building 1.7s (9/22)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.3s
#  => => transferring context: 1.46MB                                        0.3s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
# [+] Building 1.8s (9/22)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.4s
#  => => transferring context: 1.95MB                                        0.4s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
# [+] Building 1.9s (9/22)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 2.39MB                                        0.5s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
# [+] Building 2.1s (9/22)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.7s
#  => => transferring context: 3.27MB                                        0.7s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
# [+] Building 2.2s (9/22)                                   docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.8s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
# [+] Building 2.3s (10/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
# [+] Building 2.4s (11/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
# [+] Building 2.7s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       0.2s
# [+] Building 2.8s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       0.3s
# [+] Building 3.0s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       0.5s
# [+] Building 3.1s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       0.6s
# [+] Building 3.3s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       0.8s
# [+] Building 3.4s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       0.9s
#  => => # yarn install v1.22.19
# [+] Building 3.5s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       1.0s
#  => => # yarn install v1.22.19
# [+] Building 3.6s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       1.0s
#  => => # yarn install v1.22.19
#  => => # [1/4] Resolving packages...
# [+] Building 3.7s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       1.2s
#  => => # yarn install v1.22.19
#  => => # [1/4] Resolving packages...
# [+] Building 3.9s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       1.3s
#  => => # yarn install v1.22.19
#  => => # [1/4] Resolving packages...
# [+] Building 4.0s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       1.5s
#  => => # yarn install v1.22.19
#  => => # [1/4] Resolving packages...
# [+] Building 4.1s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       1.6s
#  => => # yarn install v1.22.19
#  => => # [1/4] Resolving packages...
#  => => # [2/4] Fetching packages...
# [+] Building 4.3s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       1.8s
#  => => # yarn install v1.22.19
#  => => # [1/4] Resolving packages...
#  => => # [2/4] Fetching packages...
# [+] Building 4.4s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       1.9s
#  => => # yarn install v1.22.19
#  => => # [1/4] Resolving packages...
#  => => # [2/4] Fetching packages...
# [+] Building 4.6s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       2.1s
#  => => # yarn install v1.22.19
#  => => # [1/4] Resolving packages...
#  => => # [2/4] Fetching packages...
# [+] Building 4.7s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       2.2s
#  => => # yarn install v1.22.19
#  => => # [1/4] Resolving packages...
#  => => # [2/4] Fetching packages...
# [+] Building 4.9s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       2.4s
#  => => # yarn install v1.22.19
#  => => # [1/4] Resolving packages...
#  => => # [2/4] Fetching packages...
# [+] Building 5.0s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       2.5s
#  => => # yarn install v1.22.19
#  => => # [1/4] Resolving packages...
#  => => # [2/4] Fetching packages...
# [+] Building 5.2s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                       2.7s
#  => => # yarn install v1.22.19
#  => => # [1/4] Resolving packages...
#  => => # [2/4] Fetching packages...
# [+] Building 5.3s (13/22)                                  docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
# ...
#  => [builder 10/10] RUN yarn workspace web build                          14.5s
#  => => # ged to be resolved at runtime
#  => => # /fonts/Playfair_Display/PlayfairDisplay-Regular.min.woff referenced in
#  => => #  /app/packages/ui-library/dist/style.css didn't resolve at build time,
#  => => #  it will remain unchanged to be resolved at runtime
#  => => # ✓ 481 modules transformed.
#  => => # rendering chunks...
# [+] Building 86.2s (17/22)                                 docker:desktop-linux
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                      65.9s
#  => [builder  7/10] COPY apps/web ./apps/web                               2.7s
#  => [builder  8/10] COPY packages/ui-library ./packages/ui-library         0.3s
#  => [builder  9/10] RUN find ./apps/web -name "*.stories.tsx" -type f -de  0.2s
#  => [builder 10/10] RUN yarn workspace web build                          14.6s
#  => => # ps://rollupjs.org/configuration-options/#output-manualchunks
#  => => # - Adjust chunk size limit for this warning via build.chunkSizeWarningL
#  => => # imit.
#  => => # [vite-plugin-static-copy] Copied 12 items.
#  => => # ✓ built in 5.93s
#  => => # Done in 12.81s.
# [+] Building 86.4s (18/22)                                 docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                      65.9s
#  => [builder  7/10] COPY apps/web ./apps/web                               2.7s
#  => [builder  8/10] COPY packages/ui-library ./packages/ui-library         0.3s
#  => [builder  9/10] RUN find ./apps/web -name "*.stories.tsx" -type f -de  0.2s
#  => [builder 10/10] RUN yarn workspace web build                          14.7s
#
# [+] Building 86.6s (18/22)                                 docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                      65.9s
#  => [builder  7/10] COPY apps/web ./apps/web                               2.7s
#  => [builder  8/10] COPY packages/ui-library ./packages/ui-library         0.3s
#  => [builder  9/10] RUN find ./apps/web -name "*.stories.tsx" -type f -de  0.2s
#  => [builder 10/10] RUN yarn workspace web build                          14.7s
# [+] Building 86.7s (18/22)                                 docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                      65.9s
#  => [builder  7/10] COPY apps/web ./apps/web                               2.7s
#  => [builder  8/10] COPY packages/ui-library ./packages/ui-library         0.3s
#  => [builder  9/10] RUN find ./apps/web -name "*.stories.tsx" -type f -de  0.2s
#  => [builder 10/10] RUN yarn workspace web build                          14.7s
# [+] Building 86.8s (18/22)                                 docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                      65.9s
#  => [builder  7/10] COPY apps/web ./apps/web                               2.7s
#  => [builder  8/10] COPY packages/ui-library ./packages/ui-library         0.3s
#  => [builder  9/10] RUN find ./apps/web -name "*.stories.tsx" -type f -de  0.2s
#  => [builder 10/10] RUN yarn workspace web build                          14.7s
#  => [stage-1 2/5] COPY --from=builder /app/apps/web/dist /usr/share/nginx  0.0s
# [+] Building 86.9s (21/22)                                 docker:desktop-linux
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                      65.9s
#  => [builder  7/10] COPY apps/web ./apps/web                               2.7s
#  => [builder  8/10] COPY packages/ui-library ./packages/ui-library         0.3s
#  => [builder  9/10] RUN find ./apps/web -name "*.stories.tsx" -type f -de  0.2s
#  => [builder 10/10] RUN yarn workspace web build                          14.7s
#  => [stage-1 2/5] COPY --from=builder /app/apps/web/dist /usr/share/nginx  0.0s
#  => [stage-1 3/5] COPY apps/web/startup.sh /startup.sh                     0.0s
#  => [stage-1 4/5] RUN chmod +x /startup.sh                                 0.1s
# [+] Building 87.0s (22/22)                                 docker:desktop-linux
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                      65.9s
#  => [builder  7/10] COPY apps/web ./apps/web                               2.7s
#  => [builder  8/10] COPY packages/ui-library ./packages/ui-library         0.3s
#  => [builder  9/10] RUN find ./apps/web -name "*.stories.tsx" -type f -de  0.2s
#  => [builder 10/10] RUN yarn workspace web build                          14.7s
#  => [stage-1 2/5] COPY --from=builder /app/apps/web/dist /usr/share/nginx  0.0s
#  => [stage-1 3/5] COPY apps/web/startup.sh /startup.sh                     0.0s
#  => [stage-1 4/5] RUN chmod +x /startup.sh                                 0.1s
#  => [stage-1 5/5] RUN echo 'server {     listen 8080;         gzip on;     0.1s
# [+] Building 87.1s (23/23) FINISHED                        docker:desktop-linux
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.15kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 486B                                          0.0s
#  => [internal] load metadata for docker.io/library/nginx:alpine            1.3s
#  => [internal] load metadata for docker.io/library/node:18.20.3            0.9s
#  => [auth] library/node:pull token for registry-1.docker.io                0.0s
#  => [auth] library/nginx:pull token for registry-1.docker.io               0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 3.50MB                                        0.8s
#  => CACHED [stage-1 1/5] FROM docker.io/library/nginx:alpine@sha256:a45ee  0.0s
#  => [builder  1/10] FROM docker.io/library/node:18.20.3@sha256:70ae166dcb  0.0s
#  => CACHED [builder  2/10] WORKDIR /app                                    0.0s
#  => [builder  3/10] COPY package.json yarn.lock turbo.json ./              0.1s
#  => [builder  4/10] COPY apps/web/package.json ./apps/web/                 0.0s
#  => [builder  5/10] COPY packages/ui-library/package.json ./packages/ui-l  0.0s
#  => [builder  6/10] RUN yarn install                                      65.9s
#  => [builder  7/10] COPY apps/web ./apps/web                               2.7s
#  => [builder  8/10] COPY packages/ui-library ./packages/ui-library         0.3s
#  => [builder  9/10] RUN find ./apps/web -name "*.stories.tsx" -type f -de  0.2s
#  => [builder 10/10] RUN yarn workspace web build                          14.7s
#  => [stage-1 2/5] COPY --from=builder /app/apps/web/dist /usr/share/nginx  0.0s
#  => [stage-1 3/5] COPY apps/web/startup.sh /startup.sh                     0.0s
#  => [stage-1 4/5] RUN chmod +x /startup.sh                                 0.1s
#  => [stage-1 5/5] RUN echo 'server {     listen 8080;         gzip on;     0.1s
#  => exporting to image                                                     0.0s
#  => => exporting layers                                                    0.0s
#  => => writing image sha256:e99a75f5573beb0606c8ac153f6b7d270d17ede035b08  0.0s
#  => => naming to us-central1-docker.pkg.dev/some-app-to-deploy-2/dev-repo  0.0s
#
# View build details: ]8;;docker-desktop://dashboard/build/desktop-linux/desktop-linux/ybruotjc2v44q8b6k1iplgh77\docker-desktop://dashboard/build/desktop-linux/desktop-linux/ybruotjc2v44q8b6k1iplgh77]8;;\
#
# What's Next?
#   View a summary of image vulnerabilities and recommendations → docker scout quickview

# %% [markdown]
# Push Docker Image to Artifact Registry

# %%
# !docker push {region}-docker.pkg.dev/{project_id}/{env}-repo/{env}-{service_name}:latest
# Out:
# The push refers to repository [us-central1-docker.pkg.dev/some-app-to-deploy-2/dev-repo/dev-web-service]
#
# 63706eb6: Preparing
# 8a3af0b9: Preparing
# 0bfcdf17: Preparing
# d22ebbd8: Preparing
# 172d7184: Preparing
# 6fe26981: Preparing
# 8baef084: Preparing
# f4a1b224: Preparing
# 164ce225: Preparing
# 270dbfe6: Preparing
# e1fcf1ad: Preparing
# e1fcf1ad: Pushed   5.478MB/4.607MBlatest: digest: sha256:6f0c0ed2190f9438d03182feec73025e72ebbf200bfc8092853be80223adc773 size: 2821

# %% [markdown]
# **When all of the docker images are built and pushed, you can go back to Terraform deployment notebook and run Terraform apply again. Remove the flag that prevented deployment of the services during the initial deployment.**

# %% [markdown]
# ### Optional: Deploy to Google Cloud Run

# %% [markdown]
# **Only used for debugging. Do NOT run before Terraform deploys the services to prevent conflicts in the state file.**

# %%
# !gcloud run deploy {env}-{service_name} --image {region}-docker.pkg.dev/{project_id}/{env}-repo/{env}-{service_name}:latest --platform managed --region={region} --allow-unauthenticated
# Out:
# Deploying container to Cloud Run service [dev-gateway-service] in project [some-app-to-deploy-2] region [us-central1]
# Deploying...
#   . Creating Revision...
#   . Routing traffic...
#   . Setting IAM Policy...
#   Deploying...
#
#
#
# ⠛ Deploying...
#
#
#
# ⠹ Deploying...
#
#
#
# ⠼ Deploying...
#
#
#   ⠼ Setting IAM Policy...
# ⠶ Deploying...
#
#
#   ⠶ Setting IAM Policy...
# ⠧ Deploying...
#
#
#   ⠧ Setting IAM Policy...
# ⠏ Deploying...
#
#
#   ⠏ Setting IAM Policy...
# ⠛ Deploying...
#
#
#   ⠛ Setting IAM Policy...
# ⠹ Deploying...
#
#
#   ⠹ Setting IAM Policy...
# ⠼ Deploying...
#
#
#   ⠼ Setting IAM Policy...
# ⠶ Deploying...
#
#
#   ⠶ Setting IAM Policy...
# ⠧ Deploying...
#
#
#   ⠧ Setting IAM Policy...
# ⠏ Deploying...
#
#
#   ⠏ Setting IAM Policy...
# ⠛ Deploying...
#
#
#   ⠛ Setting IAM Policy...
# ⠹ Deploying...
#
#
#   ⠹ Setting IAM Policy...
# ⠼ Deploying...
#
#
#   ⠼ Setting IAM Policy...
# ⠶ Deploying...
#
#
#   ⠶ Setting IAM Policy...
# ⠧ Deploying...
#
#
#   ⠧ Setting IAM Policy...
# ⠏ Deploying...
#
#
#   ⠏ Setting IAM Policy...
# ⠛ Deploying...
#
#
#   ⠛ Setting IAM Policy...
# ⠹ Deploying...
#
#
#   ⠹ Setting IAM Policy...
# ⠼ Deploying...
#
#
#   ⠼ Setting IAM Policy...
# ⠶ Deploying...
#
#
#   ⠶ Setting IAM Policy...
# ⠧ Deploying...
#
#
#   ⠧ Setting IAM Policy...
# ⠏ Deploying...
#
#
#   ⠏ Setting IAM Policy...
# ⠛ Deploying...
#
#
#   ✓ Setting IAM Policy...
# ⠹ Deploying...
#   ⠹ Creating Revision...
#
#
# ⠼ Deploying...
#   ⠼ Creating Revision...
#
#
# ⠶ Deploying...
#   ⠶ Creating Revision...
#
#
# ⠧ Deploying...
#   ⠧ Creating Revision...
#
#
# ⠏ Deploying...
#   ⠏ Creating Revision...
#
#
# ⠛ Deploying...
#   ⠛ Creating Revision...
#
#
# ⠹ Deploying...
#   ⠹ Creating Revision...
#
#
# ⠼ Deploying...
#   ⠼ Creating Revision...
#
#
# ⠶ Deploying...
#   ⠶ Creating Revision...
#
#
# ⠧ Deploying...
#   ⠧ Creating Revision...
#
#
# ⠏ Deploying...
#   ⠏ Creating Revision...
#
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#   ⠛ Creating Revision...
#   . Routing traffic...
#   ✓ Setting IAM Policy...
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#   ⠹ Creating Revision...
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#   ⠼ Creating Revision...
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#   ✓ Creating Revision...
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Deploying Revision. Waiting on revision dev-gateway-service-0000
# 2-xuf.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Assigning traffic to latest specified targets.
#   ✓ Creating Revision...
#   ⠼ Routing traffic...
#   ✓ Setting IAM Policy...
# ⠶ Deploying... Assigning traffic to latest specified targets.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Assigning traffic to latest specified targets.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Assigning traffic to latest specified targets.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Assigning traffic to latest specified targets.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Assigning traffic to latest specified targets.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying... Assigning traffic to latest specified targets.
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying... Assigning traffic to latest specified targets.
#
#   ⠶ Routing traffic...
#
# ⠧ Deploying... Assigning traffic to latest specified targets.
#
#   ⠧ Routing traffic...
#
# ⠏ Deploying... Assigning traffic to latest specified targets.
#
#   ⠏ Routing traffic...
#
# ⠛ Deploying... Assigning traffic to latest specified targets.
#
#   ⠛ Routing traffic...
#
# ⠹ Deploying... Assigning traffic to latest specified targets.
#
#   ⠹ Routing traffic...
#
# ⠼ Deploying...
#
#   ⠼ Routing traffic...
#
# ⠶ Deploying...
#
#   ✓ Routing traffic...
#
# ⠧ Deploying... Done.
#
#
#
# ⠏ Deploying... Done.
#
#
#
# ⠛ Deploying... Done.
#
#
#
# ⠹ Deploying... Done.
#
#
#
# ⠼ Deploying... Done.
#
#
#
# ⠶ Deploying... Done.
#
#
#
# ⠧ Deploying... Done.
#
#
#
# ⠏ Deploying... Done.
#
#
#
# ⠛ Deploying... Done.
#
#
#
# ⠹ Deploying... Done.
#
#
#
# ✓ Deploying... Done.
#
#
#
# Done.
# Service [dev-gateway-service] revision [dev-gateway-service-00002-xuf] has been deployed and is serving 100 percent of traffic.
# Service URL: https://dev-gateway-service-t2haben2kq-uc.a.run.app
