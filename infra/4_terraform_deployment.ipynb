# %% [markdown]
# # Terraform Deployment

# %% [raw]
# Initialize local variables from the shared project variables file.

# %%
from project_vars import project_variables

env = project_variables['environment']

# %% [raw]
# We need to change the current working directory to the `environments/{env}` folder so that terraform commands can be executed in the correct directory.

# %%
import os

os.chdir(f"./environments/{env}")
print("Current working directory:", os.getcwd())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/s4/kcpfybzs7xz9f8k2667jbxjc0000gn/T/ipykernel_37133/3362197617.py in <module>
#       1 import os
#       2
# ----> 3 os.chdir(f"./environments/{env}")
#       4 print("Current working directory:", os.getcwd())
#
# FileNotFoundError: [Errno 2] No such file or directory: './environments/dev'

# %% [raw]
# Initialize the terraform workspace.

# %%
# !terraform init
# Out:
# Initializing the backend...
# Initializing modules...
#
# Initializing provider plugins...
# - Reusing previous version of hashicorp/google from the dependency lock file
# - Reusing previous version of hashicorp/google-beta from the dependency lock file
# - Using previously-installed hashicorp/google v5.19.0
# - Using previously-installed hashicorp/google-beta v5.38.0
#
# Terraform has been successfully initialized!
#
# You may now begin working with Terraform. Try running "terraform plan" to see
# any changes that are required for your infrastructure. All Terraform commands
# should now work.
#
# If you ever set or change modules or backend configuration for Terraform,
# rerun this command to reinitialize your working directory. If you forget, other
# commands will detect it and remind you to do so if necessary.

# %% [raw]
# Apply the terraform changes.

# %%
# !terraform plan
# Out:
# Acquiring state lock. This may take a few moments...
# module.vpc.google_compute_network.vpc: Refreshing state... [id=projects/fs-microservices/global/networks/dev-vpc]
# module.firebase.google_project_service.firebase_api: Refreshing state... [id=fs-microservices/firebase.googleapis.com]
# module.ci_cd_service_account.google_service_account.ci_cd: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com]
# module.ci_cd_service_account.google_secret_manager_secret.ci_cd_key_secret: Refreshing state... [id=projects/fs-microservices/secrets/dev-gcp-auth-sa-key]
# module.artifact_registry.google_artifact_registry_repository.docker_repository: Refreshing state... [id=projects/fs-microservices/locations/us-central1/repositories/dev-repo]
# module.vpc.google_compute_firewall.allow_internal: Refreshing state... [id=projects/fs-microservices/global/firewalls/dev-allow-internal]
# module.vpc.google_compute_global_address.private_ip_address: Refreshing state... [id=projects/fs-microservices/global/addresses/dev-private-ip]
# module.vpc.google_compute_subnetwork.subnet: Refreshing state... [id=projects/fs-microservices/regions/us-central1/subnetworks/dev-subnet]
# module.vpc.google_compute_router.router[0]: Refreshing state... [id=projects/fs-microservices/regions/us-central1/routers/dev-router]
# module.vpc.google_compute_firewall.allow_iap_ssh: Refreshing state... [id=projects/fs-microservices/global/firewalls/dev-allow-iap-ssh]
# module.vpc.google_compute_firewall.allow_egress: Refreshing state... [id=projects/fs-microservices/global/firewalls/dev-allow-egress]
# module.ci_cd_service_account.google_project_iam_member.ci_cd_sa_permissions["roles/editor"]: Refreshing state... [id=fs-microservices/roles/editor/serviceAccount:dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com]
# module.ci_cd_service_account.google_project_iam_member.ci_cd_sa_permissions["roles/secretmanager.secretAccessor"]: Refreshing state... [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com]
# module.ci_cd_service_account.google_project_iam_member.ci_cd_sa_permissions["roles/cloudsql.client"]: Refreshing state... [id=fs-microservices/roles/cloudsql.client/serviceAccount:dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com]
# module.ci_cd_service_account.google_service_account_key.ci_cd_key: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com/keys/377e67e60f2f29e5d1d14d7d52fd8226938646a1]
# module.ci_cd_service_account.google_secret_manager_secret_version.ci_cd_key_secret_version: Refreshing state... [id=projects/526101498496/secrets/dev-gcp-auth-sa-key/versions/1]
# module.vpc.google_vpc_access_connector.connector: Refreshing state... [id=projects/fs-microservices/locations/us-central1/connectors/dev-connector]
# module.vpc.google_compute_router_nat.nat[0]: Refreshing state... [id=fs-microservices/us-central1/dev-router/dev-nat]
# module.rabbitmq.google_service_account.rabbitmq_sa: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-rabbitmq-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_sql.google_compute_global_address.private_ip_address: Refreshing state... [id=projects/fs-microservices/global/addresses/dev-db-private-ip]
# module.cloud_run_storybook.google_service_account.cloud_run_sa: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-storybook-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.rabbitmq.google_project_iam_member.rabbitmq_sa_permissions["roles/logging.logWriter"]: Refreshing state... [id=fs-microservices/roles/logging.logWriter/serviceAccount:dev-rabbitmq-sa@fs-microservices.iam.gserviceaccount.com]
# module.rabbitmq.google_project_iam_member.rabbitmq_sa_permissions["roles/monitoring.metricWriter"]: Refreshing state... [id=fs-microservices/roles/monitoring.metricWriter/serviceAccount:dev-rabbitmq-sa@fs-microservices.iam.gserviceaccount.com]
# module.rabbitmq.google_project_iam_member.rabbitmq_sa_permissions["roles/artifactregistry.reader"]: Refreshing state... [id=fs-microservices/roles/artifactregistry.reader/serviceAccount:dev-rabbitmq-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_storybook.google_project_iam_member.cloud_run_sa_secret_manager_permissions: Refreshing state... [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:dev-storybook-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.rabbitmq.google_compute_instance.rabbitmq: Refreshing state... [id=projects/fs-microservices/zones/us-central1-a/instances/dev-rabbitmq]
# module.rabbitmq.google_compute_firewall.rabbitmq: Refreshing state... [id=projects/fs-microservices/global/firewalls/dev-rabbitmq-allow]
# module.firebase.google_firebase_project.default: Refreshing state... [id=projects/fs-microservices]
# module.firebase.google_firebase_web_app.default: Refreshing state... [id=projects/fs-microservices/webApps/1:526101498496:web:66e64ad28b91a63f3f3465]
# module.firebase.data.google_firebase_web_app_config.default: Reading...
# module.firebase.data.google_firebase_web_app_config.default: Read complete after 1s [id=1:526101498496:web:66e64ad28b91a63f3f3465]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   + create
#  <= read (data resources)
#
# Terraform will perform the following actions:
#
#   # module.cloud_run_auth.data.google_iam_policy.cloud_run_policy will be read during apply
#   # (config refers to values not yet known)
#  <= data "google_iam_policy" "cloud_run_policy" {
#       + id          = (known after apply)
#       + policy_data = (known after apply)
#
#       + binding {
#           + members = [
#               + "allUsers",
#             ]
#           + role    = "roles/run.invoker"
#         }
#       + binding {
#           + members = [
#               + (known after apply),
#             ]
#           + role    = "roles/run.admin"
#         }
#     }
#
#   # module.cloud_run_auth.google_cloud_run_service.service will be created
#   + resource "google_cloud_run_service" "service" {
#       + autogenerate_revision_name = false
#       + id                         = (known after apply)
#       + location                   = "us-central1"
#       + name                       = "dev-auth-service"
#       + project                    = "fs-microservices"
#       + status                     = (known after apply)
#
#       + template {
#           + metadata {
#               + annotations      = (known after apply)
#               + generation       = (known after apply)
#               + labels           = (known after apply)
#               + name             = (known after apply)
#               + namespace        = (known after apply)
#               + resource_version = (known after apply)
#               + self_link        = (known after apply)
#               + uid              = (known after apply)
#             }
#           + spec {
#               + container_concurrency = (known after apply)
#               + service_account_name  = (known after apply)
#               + serving_state         = (known after apply)
#               + timeout_seconds       = (known after apply)
#
#               + containers {
#                   + image = "us-central1-docker.pkg.dev/fs-microservices/dev-repo/dev-auth-service:latest"
#                   + name  = (known after apply)
#
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                 }
#             }
#         }
#
#       + traffic {
#           + latest_revision = true
#           + percent         = 100
#           + url             = (known after apply)
#         }
#     }
#
#   # module.cloud_run_auth.google_cloud_run_service_iam_policy.app_service_iam will be created
#   + resource "google_cloud_run_service_iam_policy" "app_service_iam" {
#       + etag        = (known after apply)
#       + id          = (known after apply)
#       + location    = "us-central1"
#       + policy_data = (known after apply)
#       + project     = "fs-microservices"
#       + service     = "dev-auth-service"
#     }
#
#   # module.cloud_run_auth.google_compute_region_network_endpoint_group.cloudrun_neg will be created
#   + resource "google_compute_region_network_endpoint_group" "cloudrun_neg" {
#       + id                    = (known after apply)
#       + name                  = "dev-auth-service-neg"
#       + network_endpoint_type = "SERVERLESS"
#       + project               = "fs-microservices"
#       + region                = "us-central1"
#       + self_link             = (known after apply)
#
#       + cloud_run {
#           + service = "dev-auth-service"
#         }
#     }
#
#   # module.cloud_run_auth.google_project_iam_member.cloud_run_sa_secret_manager_permissions will be created
#   + resource "google_project_iam_member" "cloud_run_sa_secret_manager_permissions" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "fs-microservices"
#       + role    = "roles/secretmanager.secretAccessor"
#     }
#
#   # module.cloud_run_auth.google_project_iam_member.cloud_run_sa_sql_client_permissions[0] will be created
#   + resource "google_project_iam_member" "cloud_run_sa_sql_client_permissions" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "fs-microservices"
#       + role    = "roles/cloudsql.client"
#     }
#
#   # module.cloud_run_auth.google_service_account.cloud_run_sa will be created
#   + resource "google_service_account" "cloud_run_sa" {
#       + account_id   = "dev-auth-service-sa"
#       + disabled     = false
#       + display_name = "Service Account for auth-service Cloud Run Service"
#       + email        = (known after apply)
#       + id           = (known after apply)
#       + member       = (known after apply)
#       + name         = (known after apply)
#       + project      = "fs-microservices"
#       + unique_id    = (known after apply)
#     }
#
#   # module.cloud_run_events.data.google_iam_policy.cloud_run_policy will be read during apply
#   # (config refers to values not yet known)
#  <= data "google_iam_policy" "cloud_run_policy" {
#       + id          = (known after apply)
#       + policy_data = (known after apply)
#
#       + binding {
#           + members = [
#               + "allUsers",
#             ]
#           + role    = "roles/run.invoker"
#         }
#       + binding {
#           + members = [
#               + (known after apply),
#             ]
#           + role    = "roles/run.admin"
#         }
#     }
#
#   # module.cloud_run_events.google_cloud_run_service.service will be created
#   + resource "google_cloud_run_service" "service" {
#       + autogenerate_revision_name = false
#       + id                         = (known after apply)
#       + location                   = "us-central1"
#       + name                       = "dev-events-service"
#       + project                    = "fs-microservices"
#       + status                     = (known after apply)
#
#       + template {
#           + metadata {
#               + annotations      = (known after apply)
#               + generation       = (known after apply)
#               + labels           = (known after apply)
#               + name             = (known after apply)
#               + namespace        = (known after apply)
#               + resource_version = (known after apply)
#               + self_link        = (known after apply)
#               + uid              = (known after apply)
#             }
#           + spec {
#               + container_concurrency = (known after apply)
#               + service_account_name  = (known after apply)
#               + serving_state         = (known after apply)
#               + timeout_seconds       = (known after apply)
#
#               + containers {
#                   + image = "us-central1-docker.pkg.dev/fs-microservices/dev-repo/dev-events-service:latest"
#                   + name  = (known after apply)
#
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                 }
#             }
#         }
#
#       + traffic {
#           + latest_revision = true
#           + percent         = 100
#           + url             = (known after apply)
#         }
#     }
#
#   # module.cloud_run_events.google_cloud_run_service_iam_policy.app_service_iam will be created
#   + resource "google_cloud_run_service_iam_policy" "app_service_iam" {
#       + etag        = (known after apply)
#       + id          = (known after apply)
#       + location    = "us-central1"
#       + policy_data = (known after apply)
#       + project     = "fs-microservices"
#       + service     = "dev-events-service"
#     }
#
#   # module.cloud_run_events.google_compute_region_network_endpoint_group.cloudrun_neg will be created
#   + resource "google_compute_region_network_endpoint_group" "cloudrun_neg" {
#       + id                    = (known after apply)
#       + name                  = "dev-events-service-neg"
#       + network_endpoint_type = "SERVERLESS"
#       + project               = "fs-microservices"
#       + region                = "us-central1"
#       + self_link             = (known after apply)
#
#       + cloud_run {
#           + service = "dev-events-service"
#         }
#     }
#
#   # module.cloud_run_events.google_project_iam_member.cloud_run_sa_secret_manager_permissions will be created
#   + resource "google_project_iam_member" "cloud_run_sa_secret_manager_permissions" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "fs-microservices"
#       + role    = "roles/secretmanager.secretAccessor"
#     }
#
#   # module.cloud_run_events.google_project_iam_member.cloud_run_sa_sql_client_permissions[0] will be created
#   + resource "google_project_iam_member" "cloud_run_sa_sql_client_permissions" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "fs-microservices"
#       + role    = "roles/cloudsql.client"
#     }
#
#   # module.cloud_run_events.google_service_account.cloud_run_sa will be created
#   + resource "google_service_account" "cloud_run_sa" {
#       + account_id   = "dev-events-service-sa"
#       + disabled     = false
#       + display_name = "Service Account for events-service Cloud Run Service"
#       + email        = (known after apply)
#       + id           = (known after apply)
#       + member       = (known after apply)
#       + name         = (known after apply)
#       + project      = "fs-microservices"
#       + unique_id    = (known after apply)
#     }
#
#   # module.cloud_run_gateway.data.google_iam_policy.cloud_run_policy will be read during apply
#   # (config refers to values not yet known)
#  <= data "google_iam_policy" "cloud_run_policy" {
#       + id          = (known after apply)
#       + policy_data = (known after apply)
#
#       + binding {
#           + members = [
#               + "allUsers",
#             ]
#           + role    = "roles/run.invoker"
#         }
#       + binding {
#           + members = [
#               + (known after apply),
#             ]
#           + role    = "roles/run.admin"
#         }
#     }
#
#   # module.cloud_run_gateway.google_cloud_run_service.service will be created
#   + resource "google_cloud_run_service" "service" {
#       + autogenerate_revision_name = false
#       + id                         = (known after apply)
#       + location                   = "us-central1"
#       + name                       = "dev-gateway-service"
#       + project                    = "fs-microservices"
#       + status                     = (known after apply)
#
#       + template {
#           + metadata {
#               + annotations      = {
#                   + "autoscaling.knative.dev/maxScale"        = "10"
#                   + "autoscaling.knative.dev/minScale"        = "0"
#                   + "run.googleapis.com/vpc-access-connector" = "dev-connector"
#                   + "run.googleapis.com/vpc-access-egress"    = "all-traffic"
#                 }
#               + generation       = (known after apply)
#               + labels           = (known after apply)
#               + name             = (known after apply)
#               + namespace        = (known after apply)
#               + resource_version = (known after apply)
#               + self_link        = (known after apply)
#               + uid              = (known after apply)
#             }
#           + spec {
#               + container_concurrency = (known after apply)
#               + service_account_name  = (known after apply)
#               + serving_state         = (known after apply)
#               + timeout_seconds       = (known after apply)
#
#               + containers {
#                   + image = "us-central1-docker.pkg.dev/fs-microservices/dev-repo/dev-gateway-service:latest"
#                   + name  = (known after apply)
#
#                   + env {
#                       + name  = "APP_NAME"
#                       + value = "Gateway Microservice"
#                     }
#                   + env {
#                       + name  = "AUTH_URL"
#                       + value = (known after apply)
#                     }
#                   + env {
#                       + name  = "EVENTS_URL"
#                       + value = (known after apply)
#                     }
#                   + env {
#                       + name  = "NODE_ENV"
#                       + value = "dev"
#                     }
#                 }
#             }
#         }
#
#       + traffic {
#           + latest_revision = true
#           + percent         = 100
#           + url             = (known after apply)
#         }
#     }
#
#   # module.cloud_run_gateway.google_cloud_run_service_iam_policy.app_service_iam will be created
#   + resource "google_cloud_run_service_iam_policy" "app_service_iam" {
#       + etag        = (known after apply)
#       + id          = (known after apply)
#       + location    = "us-central1"
#       + policy_data = (known after apply)
#       + project     = "fs-microservices"
#       + service     = "dev-gateway-service"
#     }
#
#   # module.cloud_run_gateway.google_compute_region_network_endpoint_group.cloudrun_neg will be created
#   + resource "google_compute_region_network_endpoint_group" "cloudrun_neg" {
#       + id                    = (known after apply)
#       + name                  = "dev-gateway-service-neg"
#       + network_endpoint_type = "SERVERLESS"
#       + project               = "fs-microservices"
#       + region                = "us-central1"
#       + self_link             = (known after apply)
#
#       + cloud_run {
#           + service = "dev-gateway-service"
#         }
#     }
#
#   # module.cloud_run_gateway.google_project_iam_member.cloud_run_sa_secret_manager_permissions will be created
#   + resource "google_project_iam_member" "cloud_run_sa_secret_manager_permissions" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "fs-microservices"
#       + role    = "roles/secretmanager.secretAccessor"
#     }
#
#   # module.cloud_run_gateway.google_service_account.cloud_run_sa will be created
#   + resource "google_service_account" "cloud_run_sa" {
#       + account_id   = "dev-gateway-service-sa"
#       + disabled     = false
#       + display_name = "Service Account for gateway-service Cloud Run Service"
#       + email        = (known after apply)
#       + id           = (known after apply)
#       + member       = (known after apply)
#       + name         = (known after apply)
#       + project      = "fs-microservices"
#       + unique_id    = (known after apply)
#     }
#
#   # module.cloud_run_storybook.data.google_iam_policy.cloud_run_policy will be read during apply
#   # (depends on a resource or a module with changes pending)
#  <= data "google_iam_policy" "cloud_run_policy" {
#       + id          = (known after apply)
#       + policy_data = (known after apply)
#
#       + binding {
#           + members = [
#               + "allUsers",
#             ]
#           + role    = "roles/run.invoker"
#         }
#       + binding {
#           + members = [
#               + "serviceAccount:dev-storybook-service-sa@fs-microservices.iam.gserviceaccount.com",
#             ]
#           + role    = "roles/run.admin"
#         }
#     }
#
#   # module.cloud_run_storybook.google_cloud_run_service.service will be created
#   + resource "google_cloud_run_service" "service" {
#       + autogenerate_revision_name = false
#       + id                         = (known after apply)
#       + location                   = "us-central1"
#       + name                       = "dev-storybook-service"
#       + project                    = "fs-microservices"
#       + status                     = (known after apply)
#
#       + template {
#           + metadata {
#               + annotations      = {
#                   + "autoscaling.knative.dev/maxScale"        = "10"
#                   + "autoscaling.knative.dev/minScale"        = "0"
#                   + "run.googleapis.com/vpc-access-connector" = "dev-connector"
#                   + "run.googleapis.com/vpc-access-egress"    = "all-traffic"
#                 }
#               + generation       = (known after apply)
#               + labels           = (known after apply)
#               + name             = (known after apply)
#               + namespace        = (known after apply)
#               + resource_version = (known after apply)
#               + self_link        = (known after apply)
#               + uid              = (known after apply)
#             }
#           + spec {
#               + container_concurrency = (known after apply)
#               + service_account_name  = "dev-storybook-service-sa@fs-microservices.iam.gserviceaccount.com"
#               + serving_state         = (known after apply)
#               + timeout_seconds       = (known after apply)
#
#               + containers {
#                   + image = "us-central1-docker.pkg.dev/fs-microservices/dev-repo/dev-storybook-service:latest"
#                   + name  = (known after apply)
#
#                   + env {
#                       + name  = "NODE_ENV"
#                       + value = "dev"
#                     }
#                 }
#             }
#         }
#
#       + traffic {
#           + latest_revision = true
#           + percent         = 100
#           + url             = (known after apply)
#         }
#     }
#
#   # module.cloud_run_storybook.google_cloud_run_service_iam_policy.app_service_iam will be created
#   + resource "google_cloud_run_service_iam_policy" "app_service_iam" {
#       + etag        = (known after apply)
#       + id          = (known after apply)
#       + location    = "us-central1"
#       + policy_data = (known after apply)
#       + project     = "fs-microservices"
#       + service     = "dev-storybook-service"
#     }
#
#   # module.cloud_run_storybook.google_compute_region_network_endpoint_group.cloudrun_neg will be created
#   + resource "google_compute_region_network_endpoint_group" "cloudrun_neg" {
#       + id                    = (known after apply)
#       + name                  = "dev-storybook-service-neg"
#       + network_endpoint_type = "SERVERLESS"
#       + project               = "fs-microservices"
#       + region                = "us-central1"
#       + self_link             = (known after apply)
#
#       + cloud_run {
#           + service = "dev-storybook-service"
#         }
#     }
#
#   # module.cloud_run_web.data.google_iam_policy.cloud_run_policy will be read during apply
#   # (config refers to values not yet known)
#  <= data "google_iam_policy" "cloud_run_policy" {
#       + id          = (known after apply)
#       + policy_data = (known after apply)
#
#       + binding {
#           + members = [
#               + "allUsers",
#             ]
#           + role    = "roles/run.invoker"
#         }
#       + binding {
#           + members = [
#               + (known after apply),
#             ]
#           + role    = "roles/run.admin"
#         }
#     }
#
#   # module.cloud_run_web.google_cloud_run_service.service will be created
#   + resource "google_cloud_run_service" "service" {
#       + autogenerate_revision_name = false
#       + id                         = (known after apply)
#       + location                   = "us-central1"
#       + name                       = "dev-web-service"
#       + project                    = "fs-microservices"
#       + status                     = (known after apply)
#
#       + template {
#           + metadata {
#               + annotations      = {
#                   + "autoscaling.knative.dev/maxScale"        = "10"
#                   + "autoscaling.knative.dev/minScale"        = "0"
#                   + "run.googleapis.com/vpc-access-connector" = "dev-connector"
#                   + "run.googleapis.com/vpc-access-egress"    = "all-traffic"
#                 }
#               + generation       = (known after apply)
#               + labels           = (known after apply)
#               + name             = (known after apply)
#               + namespace        = (known after apply)
#               + resource_version = (known after apply)
#               + self_link        = (known after apply)
#               + uid              = (known after apply)
#             }
#           + spec {
#               + container_concurrency = (known after apply)
#               + service_account_name  = (known after apply)
#               + serving_state         = (known after apply)
#               + timeout_seconds       = (known after apply)
#
#               + containers {
#                   + image = "us-central1-docker.pkg.dev/fs-microservices/dev-repo/dev-web-service:latest"
#                   + name  = (known after apply)
#
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                 }
#             }
#         }
#
#       + traffic {
#           + latest_revision = true
#           + percent         = 100
#           + url             = (known after apply)
#         }
#     }
#
#   # module.cloud_run_web.google_cloud_run_service_iam_policy.app_service_iam will be created
#   + resource "google_cloud_run_service_iam_policy" "app_service_iam" {
#       + etag        = (known after apply)
#       + id          = (known after apply)
#       + location    = "us-central1"
#       + policy_data = (known after apply)
#       + project     = "fs-microservices"
#       + service     = "dev-web-service"
#     }
#
#   # module.cloud_run_web.google_compute_region_network_endpoint_group.cloudrun_neg will be created
#   + resource "google_compute_region_network_endpoint_group" "cloudrun_neg" {
#       + id                    = (known after apply)
#       + name                  = "dev-web-service-neg"
#       + network_endpoint_type = "SERVERLESS"
#       + project               = "fs-microservices"
#       + region                = "us-central1"
#       + self_link             = (known after apply)
#
#       + cloud_run {
#           + service = "dev-web-service"
#         }
#     }
#
#   # module.cloud_run_web.google_project_iam_member.cloud_run_sa_secret_manager_permissions will be created
#   + resource "google_project_iam_member" "cloud_run_sa_secret_manager_permissions" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "fs-microservices"
#       + role    = "roles/secretmanager.secretAccessor"
#     }
#
#   # module.cloud_run_web.google_service_account.cloud_run_sa will be created
#   + resource "google_service_account" "cloud_run_sa" {
#       + account_id   = "dev-web-service-sa"
#       + disabled     = false
#       + display_name = "Service Account for web-service Cloud Run Service"
#       + email        = (known after apply)
#       + id           = (known after apply)
#       + member       = (known after apply)
#       + name         = (known after apply)
#       + project      = "fs-microservices"
#       + unique_id    = (known after apply)
#     }
#
#   # module.cloud_sql.data.google_compute_default_service_account.default will be read during apply
#   # (depends on a resource or a module with changes pending)
#  <= data "google_compute_default_service_account" "default" {
#       + display_name = (known after apply)
#       + email        = (known after apply)
#       + id           = (known after apply)
#       + member       = (known after apply)
#       + name         = (known after apply)
#       + project      = "fs-microservices"
#       + unique_id    = (known after apply)
#     }
#
#   # module.cloud_sql.data.google_secret_manager_secret_version.db_passwords["auth"] will be read during apply
#   # (depends on a resource or a module with changes pending)
#  <= data "google_secret_manager_secret_version" "db_passwords" {
#       + create_time  = (known after apply)
#       + destroy_time = (known after apply)
#       + enabled      = (known after apply)
#       + id           = (known after apply)
#       + name         = (known after apply)
#       + project      = "fs-microservices"
#       + secret       = "dev-auth-db-password"
#       + secret_data  = (sensitive value)
#       + version      = (known after apply)
#     }
#
#   # module.cloud_sql.data.google_secret_manager_secret_version.db_passwords["events"] will be read during apply
#   # (depends on a resource or a module with changes pending)
#  <= data "google_secret_manager_secret_version" "db_passwords" {
#       + create_time  = (known after apply)
#       + destroy_time = (known after apply)
#       + enabled      = (known after apply)
#       + id           = (known after apply)
#       + name         = (known after apply)
#       + project      = "fs-microservices"
#       + secret       = "dev-events-db-password"
#       + secret_data  = (sensitive value)
#       + version      = (known after apply)
#     }
#
#   # module.cloud_sql.data.google_secret_manager_secret_version.db_usernames["auth"] will be read during apply
#   # (depends on a resource or a module with changes pending)
#  <= data "google_secret_manager_secret_version" "db_usernames" {
#       + create_time  = (known after apply)
#       + destroy_time = (known after apply)
#       + enabled      = (known after apply)
#       + id           = (known after apply)
#       + name         = (known after apply)
#       + project      = "fs-microservices"
#       + secret       = "dev-auth-db-user"
#       + secret_data  = (sensitive value)
#       + version      = (known after apply)
#     }
#
#   # module.cloud_sql.data.google_secret_manager_secret_version.db_usernames["events"] will be read during apply
#   # (depends on a resource or a module with changes pending)
#  <= data "google_secret_manager_secret_version" "db_usernames" {
#       + create_time  = (known after apply)
#       + destroy_time = (known after apply)
#       + enabled      = (known after apply)
#       + id           = (known after apply)
#       + name         = (known after apply)
#       + project      = "fs-microservices"
#       + secret       = "dev-events-db-user"
#       + secret_data  = (sensitive value)
#       + version      = (known after apply)
#     }
#
#   # module.cloud_sql.google_project_iam_member.default_sa_cloudsql_client_permissions will be created
#   + resource "google_project_iam_member" "default_sa_cloudsql_client_permissions" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "fs-microservices"
#       + role    = "roles/cloudsql.client"
#     }
#
#   # module.cloud_sql.google_project_iam_member.default_sa_secret_manager_permissions will be created
#   + resource "google_project_iam_member" "default_sa_secret_manager_permissions" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "fs-microservices"
#       + role    = "roles/secretmanager.secretAccessor"
#     }
#
#   # module.cloud_sql.google_sql_database.databases["auth"] will be created
#   + resource "google_sql_database" "databases" {
#       + charset         = (known after apply)
#       + collation       = (known after apply)
#       + deletion_policy = "DELETE"
#       + id              = (known after apply)
#       + instance        = "dev-db-instance"
#       + name            = "auth_db"
#       + project         = "fs-microservices"
#       + self_link       = (known after apply)
#     }
#
#   # module.cloud_sql.google_sql_database.databases["events"] will be created
#   + resource "google_sql_database" "databases" {
#       + charset         = (known after apply)
#       + collation       = (known after apply)
#       + deletion_policy = "DELETE"
#       + id              = (known after apply)
#       + instance        = "dev-db-instance"
#       + name            = "events_db"
#       + project         = "fs-microservices"
#       + self_link       = (known after apply)
#     }
#
#   # module.cloud_sql.google_sql_database_instance.postgres_instance will be created
#   + resource "google_sql_database_instance" "postgres_instance" {
#       + available_maintenance_versions = (known after apply)
#       + connection_name                = (known after apply)
#       + database_version               = "POSTGRES_14"
#       + deletion_protection            = false
#       + dns_name                       = (known after apply)
#       + encryption_key_name            = (known after apply)
#       + first_ip_address               = (known after apply)
#       + id                             = (known after apply)
#       + instance_type                  = (known after apply)
#       + ip_address                     = (known after apply)
#       + maintenance_version            = (known after apply)
#       + master_instance_name           = (known after apply)
#       + name                           = "dev-db-instance"
#       + private_ip_address             = (known after apply)
#       + project                        = "fs-microservices"
#       + psc_service_attachment_link    = (known after apply)
#       + public_ip_address              = (known after apply)
#       + region                         = "us-central1"
#       + self_link                      = (known after apply)
#       + server_ca_cert                 = (sensitive value)
#       + service_account_email_address  = (known after apply)
#
#       + settings {
#           + activation_policy     = "ALWAYS"
#           + availability_type     = "ZONAL"
#           + connector_enforcement = (known after apply)
#           + disk_autoresize       = true
#           + disk_autoresize_limit = 0
#           + disk_size             = (known after apply)
#           + disk_type             = "PD_SSD"
#           + edition               = "ENTERPRISE"
#           + pricing_plan          = "PER_USE"
#           + tier                  = "db-f1-micro"
#           + user_labels           = {
#               + "environment" = "dev"
#             }
#           + version               = (known after apply)
#
#           + ip_configuration {
#               + ipv4_enabled    = false
#               + private_network = "https://www.googleapis.com/compute/v1/projects/fs-microservices/global/networks/dev-vpc"
#               + ssl_mode        = (known after apply)
#
#               + authorized_networks {
#                   + name  = "home-network-1"
#                   + value = "86.49.224.158/32"
#                 }
#             }
#         }
#     }
#
#   # module.cloud_sql.google_sql_user.database_users["auth"] will be created
#   + resource "google_sql_user" "database_users" {
#       + host                    = (known after apply)
#       + id                      = (known after apply)
#       + instance                = "dev-db-instance"
#       + name                    = (sensitive value)
#       + password                = (sensitive value)
#       + project                 = "fs-microservices"
#       + sql_server_user_details = (known after apply)
#     }
#
#   # module.cloud_sql.google_sql_user.database_users["events"] will be created
#   + resource "google_sql_user" "database_users" {
#       + host                    = (known after apply)
#       + id                      = (known after apply)
#       + instance                = "dev-db-instance"
#       + name                    = (sensitive value)
#       + password                = (sensitive value)
#       + project                 = "fs-microservices"
#       + sql_server_user_details = (known after apply)
#     }
#
#   # module.rabbitmq.data.google_compute_default_service_account.default will be read during apply
#   # (depends on a resource or a module with changes pending)
#  <= data "google_compute_default_service_account" "default" {
#       + display_name = (known after apply)
#       + email        = (known after apply)
#       + id           = (known after apply)
#       + member       = (known after apply)
#       + name         = (known after apply)
#       + project      = (known after apply)
#       + unique_id    = (known after apply)
#     }
#
#   # module.rabbitmq.google_project_iam_member.iap_tunnel_user will be created
#   + resource "google_project_iam_member" "iap_tunnel_user" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "fs-microservices"
#       + role    = "roles/iap.tunnelResourceAccessor"
#     }
#
#   # module.vpc.google_service_networking_connection.private_vpc_connection["projects/fs-microservices/global/networks/dev-vpc"] will be created
#   + resource "google_service_networking_connection" "private_vpc_connection" {
#       + id                      = (known after apply)
#       + network                 = "projects/fs-microservices/global/networks/dev-vpc"
#       + peering                 = (known after apply)
#       + reserved_peering_ranges = [
#           + "dev-private-ip",
#         ]
#       + service                 = "servicenetworking.googleapis.com"
#     }
#
# Plan: 34 to add, 0 to change, 0 to destroy.
# ╷
# │ Warning: Value for undeclared variable
# │
# │ The root module does not declare a variable named "project_name" but a value
# │ was found in file "terraform.tfvars". If you meant to use this value, add a
# │ "variable" block to the configuration.
# │
# │ To silence these warnings, use TF_VAR_... environment variables to provide
# │ certain "global" settings to all configurations in your organization. To
# │ reduce the verbosity of these warnings, use the -compact-warnings option.
# ╵
# ╷
# │ Warning: Value for undeclared variable
# │
# │ The root module does not declare a variable named "bucket_name" but a value
# │ was found in file "terraform.tfvars". If you meant to use this value, add a
# │ "variable" block to the configuration.
# │
# │ To silence these warnings, use TF_VAR_... environment variables to provide
# │ certain "global" settings to all configurations in your organization. To
# │ reduce the verbosity of these warnings, use the -compact-warnings option.
# ╵
#
# ───────────────────────────────────────────────────────────────────────────────
#
# Note: You didn't use the -out option to save this plan, so Terraform can't
# guarantee to take exactly these actions if you run "terraform apply" now.

# %% [raw]
# Note: The following command will fail with an error because we haven't uploaded Docker image yet.

# %%
# !terraform apply --auto-approve
# Out:
# Acquiring state lock. This may take a few moments...
# module.firebase.google_project_service.firebase_api: Refreshing state... [id=fs-microservices/firebase.googleapis.com]
# module.ci_cd_service_account.google_service_account.ci_cd: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com]
# module.vpc.google_compute_network.vpc: Refreshing state... [id=projects/fs-microservices/global/networks/dev-vpc]
# module.artifact_registry.google_artifact_registry_repository.docker_repository: Refreshing state... [id=projects/fs-microservices/locations/us-central1/repositories/dev-repo]
# module.ci_cd_service_account.google_secret_manager_secret.ci_cd_key_secret: Refreshing state... [id=projects/fs-microservices/secrets/dev-gcp-auth-sa-key]
# module.vpc.google_compute_global_address.private_ip_address: Refreshing state... [id=projects/fs-microservices/global/addresses/dev-private-ip]
# module.vpc.google_compute_subnetwork.subnet: Refreshing state... [id=projects/fs-microservices/regions/us-central1/subnetworks/dev-subnet]
# module.vpc.google_compute_router.router[0]: Refreshing state... [id=projects/fs-microservices/regions/us-central1/routers/dev-router]
# module.vpc.google_compute_firewall.allow_egress: Refreshing state... [id=projects/fs-microservices/global/firewalls/dev-allow-egress]
# module.vpc.google_compute_firewall.allow_iap_ssh: Refreshing state... [id=projects/fs-microservices/global/firewalls/dev-allow-iap-ssh]
# module.vpc.google_compute_firewall.allow_internal: Refreshing state... [id=projects/fs-microservices/global/firewalls/dev-allow-internal]
# module.ci_cd_service_account.google_project_iam_member.ci_cd_sa_permissions["roles/editor"]: Refreshing state... [id=fs-microservices/roles/editor/serviceAccount:dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com]
# module.ci_cd_service_account.google_service_account_key.ci_cd_key: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com/keys/377e67e60f2f29e5d1d14d7d52fd8226938646a1]
# module.ci_cd_service_account.google_project_iam_member.ci_cd_sa_permissions["roles/secretmanager.secretAccessor"]: Refreshing state... [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com]
# module.ci_cd_service_account.google_project_iam_member.ci_cd_sa_permissions["roles/cloudsql.client"]: Refreshing state... [id=fs-microservices/roles/cloudsql.client/serviceAccount:dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com]
# module.ci_cd_service_account.google_secret_manager_secret_version.ci_cd_key_secret_version: Refreshing state... [id=projects/526101498496/secrets/dev-gcp-auth-sa-key/versions/1]
# module.vpc.google_vpc_access_connector.connector: Refreshing state... [id=projects/fs-microservices/locations/us-central1/connectors/dev-connector]
# module.vpc.google_compute_router_nat.nat[0]: Refreshing state... [id=fs-microservices/us-central1/dev-router/dev-nat]
# module.cloud_sql.google_compute_global_address.private_ip_address: Refreshing state... [id=projects/fs-microservices/global/addresses/dev-db-private-ip]
# module.cloud_run_storybook.google_service_account.cloud_run_sa: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-storybook-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.rabbitmq.google_service_account.rabbitmq_sa: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-rabbitmq-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_storybook.google_project_iam_member.cloud_run_sa_secret_manager_permissions: Refreshing state... [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:dev-storybook-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.rabbitmq.google_project_iam_member.rabbitmq_sa_permissions["roles/logging.logWriter"]: Refreshing state... [id=fs-microservices/roles/logging.logWriter/serviceAccount:dev-rabbitmq-sa@fs-microservices.iam.gserviceaccount.com]
# module.rabbitmq.google_project_iam_member.rabbitmq_sa_permissions["roles/monitoring.metricWriter"]: Refreshing state... [id=fs-microservices/roles/monitoring.metricWriter/serviceAccount:dev-rabbitmq-sa@fs-microservices.iam.gserviceaccount.com]
# module.rabbitmq.google_project_iam_member.rabbitmq_sa_permissions["roles/artifactregistry.reader"]: Refreshing state... [id=fs-microservices/roles/artifactregistry.reader/serviceAccount:dev-rabbitmq-sa@fs-microservices.iam.gserviceaccount.com]
# module.rabbitmq.google_compute_instance.rabbitmq: Refreshing state... [id=projects/fs-microservices/zones/us-central1-a/instances/dev-rabbitmq]
# module.firebase.google_firebase_project.default: Refreshing state... [id=projects/fs-microservices]
# module.firebase.google_firebase_web_app.default: Refreshing state... [id=projects/fs-microservices/webApps/1:526101498496:web:66e64ad28b91a63f3f3465]
# module.rabbitmq.google_compute_firewall.rabbitmq: Refreshing state... [id=projects/fs-microservices/global/firewalls/dev-rabbitmq-allow]
# module.firebase.data.google_firebase_web_app_config.default: Reading...
# module.firebase.data.google_firebase_web_app_config.default: Read complete after 1s [id=1:526101498496:web:66e64ad28b91a63f3f3465]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   + create
#  <= read (data resources)
#
# Terraform will perform the following actions:
#
#   # module.cloud_run_auth.data.google_iam_policy.cloud_run_policy will be read during apply
#   # (config refers to values not yet known)
#  <= data "google_iam_policy" "cloud_run_policy" {
#       + id          = (known after apply)
#       + policy_data = (known after apply)
#
#       + binding {
#           + members = [
#               + "allUsers",
#             ]
#           + role    = "roles/run.invoker"
#         }
#       + binding {
#           + members = [
#               + (known after apply),
#             ]
#           + role    = "roles/run.admin"
#         }
#     }
#
#   # module.cloud_run_auth.google_cloud_run_service.service will be created
#   + resource "google_cloud_run_service" "service" {
#       + autogenerate_revision_name = false
#       + id                         = (known after apply)
#       + location                   = "us-central1"
#       + name                       = "dev-auth-service"
#       + project                    = "fs-microservices"
#       + status                     = (known after apply)
#
#       + template {
#           + metadata {
#               + annotations      = (known after apply)
#               + generation       = (known after apply)
#               + labels           = (known after apply)
#               + name             = (known after apply)
#               + namespace        = (known after apply)
#               + resource_version = (known after apply)
#               + self_link        = (known after apply)
#               + uid              = (known after apply)
#             }
#           + spec {
#               + container_concurrency = (known after apply)
#               + service_account_name  = (known after apply)
#               + serving_state         = (known after apply)
#               + timeout_seconds       = (known after apply)
#
#               + containers {
#                   + image = "us-central1-docker.pkg.dev/fs-microservices/dev-repo/dev-auth-service:latest"
#                   + name  = (known after apply)
#
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                 }
#             }
#         }
#
#       + traffic {
#           + latest_revision = true
#           + percent         = 100
#           + url             = (known after apply)
#         }
#     }
#
#   # module.cloud_run_auth.google_cloud_run_service_iam_policy.app_service_iam will be created
#   + resource "google_cloud_run_service_iam_policy" "app_service_iam" {
#       + etag        = (known after apply)
#       + id          = (known after apply)
#       + location    = "us-central1"
#       + policy_data = (known after apply)
#       + project     = "fs-microservices"
#       + service     = "dev-auth-service"
#     }
#
#   # module.cloud_run_auth.google_compute_region_network_endpoint_group.cloudrun_neg will be created
#   + resource "google_compute_region_network_endpoint_group" "cloudrun_neg" {
#       + id                    = (known after apply)
#       + name                  = "dev-auth-service-neg"
#       + network_endpoint_type = "SERVERLESS"
#       + project               = "fs-microservices"
#       + region                = "us-central1"
#       + self_link             = (known after apply)
#
#       + cloud_run {
#           + service = "dev-auth-service"
#         }
#     }
#
#   # module.cloud_run_auth.google_project_iam_member.cloud_run_sa_secret_manager_permissions will be created
#   + resource "google_project_iam_member" "cloud_run_sa_secret_manager_permissions" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "fs-microservices"
#       + role    = "roles/secretmanager.secretAccessor"
#     }
#
#   # module.cloud_run_auth.google_project_iam_member.cloud_run_sa_sql_client_permissions[0] will be created
#   + resource "google_project_iam_member" "cloud_run_sa_sql_client_permissions" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "fs-microservices"
#       + role    = "roles/cloudsql.client"
#     }
#
#   # module.cloud_run_auth.google_service_account.cloud_run_sa will be created
#   + resource "google_service_account" "cloud_run_sa" {
#       + account_id   = "dev-auth-service-sa"
#       + disabled     = false
#       + display_name = "Service Account for auth-service Cloud Run Service"
#       + email        = (known after apply)
#       + id           = (known after apply)
#       + member       = (known after apply)
#       + name         = (known after apply)
#       + project      = "fs-microservices"
#       + unique_id    = (known after apply)
#     }
#
#   # module.cloud_run_events.data.google_iam_policy.cloud_run_policy will be read during apply
#   # (config refers to values not yet known)
#  <= data "google_iam_policy" "cloud_run_policy" {
#       + id          = (known after apply)
#       + policy_data = (known after apply)
#
#       + binding {
#           + members = [
#               + "allUsers",
#             ]
#           + role    = "roles/run.invoker"
#         }
#       + binding {
#           + members = [
#               + (known after apply),
#             ]
#           + role    = "roles/run.admin"
#         }
#     }
#
#   # module.cloud_run_events.google_cloud_run_service.service will be created
#   + resource "google_cloud_run_service" "service" {
#       + autogenerate_revision_name = false
#       + id                         = (known after apply)
#       + location                   = "us-central1"
#       + name                       = "dev-events-service"
#       + project                    = "fs-microservices"
#       + status                     = (known after apply)
#
#       + template {
#           + metadata {
#               + annotations      = (known after apply)
#               + generation       = (known after apply)
#               + labels           = (known after apply)
#               + name             = (known after apply)
#               + namespace        = (known after apply)
#               + resource_version = (known after apply)
#               + self_link        = (known after apply)
#               + uid              = (known after apply)
#             }
#           + spec {
#               + container_concurrency = (known after apply)
#               + service_account_name  = (known after apply)
#               + serving_state         = (known after apply)
#               + timeout_seconds       = (known after apply)
#
#               + containers {
#                   + image = "us-central1-docker.pkg.dev/fs-microservices/dev-repo/dev-events-service:latest"
#                   + name  = (known after apply)
#
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                 }
#             }
#         }
#
#       + traffic {
#           + latest_revision = true
#           + percent         = 100
#           + url             = (known after apply)
#         }
#     }
#
#   # module.cloud_run_events.google_cloud_run_service_iam_policy.app_service_iam will be created
#   + resource "google_cloud_run_service_iam_policy" "app_service_iam" {
#       + etag        = (known after apply)
#       + id          = (known after apply)
#       + location    = "us-central1"
#       + policy_data = (known after apply)
#       + project     = "fs-microservices"
#       + service     = "dev-events-service"
#     }
#
#   # module.cloud_run_events.google_compute_region_network_endpoint_group.cloudrun_neg will be created
#   + resource "google_compute_region_network_endpoint_group" "cloudrun_neg" {
#       + id                    = (known after apply)
#       + name                  = "dev-events-service-neg"
#       + network_endpoint_type = "SERVERLESS"
#       + project               = "fs-microservices"
#       + region                = "us-central1"
#       + self_link             = (known after apply)
#
#       + cloud_run {
#           + service = "dev-events-service"
#         }
#     }
#
#   # module.cloud_run_events.google_project_iam_member.cloud_run_sa_secret_manager_permissions will be created
#   + resource "google_project_iam_member" "cloud_run_sa_secret_manager_permissions" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "fs-microservices"
#       + role    = "roles/secretmanager.secretAccessor"
#     }
#
#   # module.cloud_run_events.google_project_iam_member.cloud_run_sa_sql_client_permissions[0] will be created
#   + resource "google_project_iam_member" "cloud_run_sa_sql_client_permissions" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "fs-microservices"
#       + role    = "roles/cloudsql.client"
#     }
#
#   # module.cloud_run_events.google_service_account.cloud_run_sa will be created
#   + resource "google_service_account" "cloud_run_sa" {
#       + account_id   = "dev-events-service-sa"
#       + disabled     = false
#       + display_name = "Service Account for events-service Cloud Run Service"
#       + email        = (known after apply)
#       + id           = (known after apply)
#       + member       = (known after apply)
#       + name         = (known after apply)
#       + project      = "fs-microservices"
#       + unique_id    = (known after apply)
#     }
#
#   # module.cloud_run_gateway.data.google_iam_policy.cloud_run_policy will be read during apply
#   # (config refers to values not yet known)
#  <= data "google_iam_policy" "cloud_run_policy" {
#       + id          = (known after apply)
#       + policy_data = (known after apply)
#
#       + binding {
#           + members = [
#               + "allUsers",
#             ]
#           + role    = "roles/run.invoker"
#         }
#       + binding {
#           + members = [
#               + (known after apply),
#             ]
#           + role    = "roles/run.admin"
#         }
#     }
#
#   # module.cloud_run_gateway.google_cloud_run_service.service will be created
#   + resource "google_cloud_run_service" "service" {
#       + autogenerate_revision_name = false
#       + id                         = (known after apply)
#       + location                   = "us-central1"
#       + name                       = "dev-gateway-service"
#       + project                    = "fs-microservices"
#       + status                     = (known after apply)
#
#       + template {
#           + metadata {
#               + annotations      = {
#                   + "autoscaling.knative.dev/maxScale"        = "10"
#                   + "autoscaling.knative.dev/minScale"        = "0"
#                   + "run.googleapis.com/vpc-access-connector" = "dev-connector"
#                   + "run.googleapis.com/vpc-access-egress"    = "all-traffic"
#                 }
#               + generation       = (known after apply)
#               + labels           = (known after apply)
#               + name             = (known after apply)
#               + namespace        = (known after apply)
#               + resource_version = (known after apply)
#               + self_link        = (known after apply)
#               + uid              = (known after apply)
#             }
#           + spec {
#               + container_concurrency = (known after apply)
#               + service_account_name  = (known after apply)
#               + serving_state         = (known after apply)
#               + timeout_seconds       = (known after apply)
#
#               + containers {
#                   + image = "us-central1-docker.pkg.dev/fs-microservices/dev-repo/dev-gateway-service:latest"
#                   + name  = (known after apply)
#
#                   + env {
#                       + name  = "APP_NAME"
#                       + value = "Gateway Microservice"
#                     }
#                   + env {
#                       + name  = "AUTH_URL"
#                       + value = (known after apply)
#                     }
#                   + env {
#                       + name  = "EVENTS_URL"
#                       + value = (known after apply)
#                     }
#                   + env {
#                       + name  = "NODE_ENV"
#                       + value = "dev"
#                     }
#                 }
#             }
#         }
#
#       + traffic {
#           + latest_revision = true
#           + percent         = 100
#           + url             = (known after apply)
#         }
#     }
#
#   # module.cloud_run_gateway.google_cloud_run_service_iam_policy.app_service_iam will be created
#   + resource "google_cloud_run_service_iam_policy" "app_service_iam" {
#       + etag        = (known after apply)
#       + id          = (known after apply)
#       + location    = "us-central1"
#       + policy_data = (known after apply)
#       + project     = "fs-microservices"
#       + service     = "dev-gateway-service"
#     }
#
#   # module.cloud_run_gateway.google_compute_region_network_endpoint_group.cloudrun_neg will be created
#   + resource "google_compute_region_network_endpoint_group" "cloudrun_neg" {
#       + id                    = (known after apply)
#       + name                  = "dev-gateway-service-neg"
#       + network_endpoint_type = "SERVERLESS"
#       + project               = "fs-microservices"
#       + region                = "us-central1"
#       + self_link             = (known after apply)
#
#       + cloud_run {
#           + service = "dev-gateway-service"
#         }
#     }
#
#   # module.cloud_run_gateway.google_project_iam_member.cloud_run_sa_secret_manager_permissions will be created
#   + resource "google_project_iam_member" "cloud_run_sa_secret_manager_permissions" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "fs-microservices"
#       + role    = "roles/secretmanager.secretAccessor"
#     }
#
#   # module.cloud_run_gateway.google_service_account.cloud_run_sa will be created
#   + resource "google_service_account" "cloud_run_sa" {
#       + account_id   = "dev-gateway-service-sa"
#       + disabled     = false
#       + display_name = "Service Account for gateway-service Cloud Run Service"
#       + email        = (known after apply)
#       + id           = (known after apply)
#       + member       = (known after apply)
#       + name         = (known after apply)
#       + project      = "fs-microservices"
#       + unique_id    = (known after apply)
#     }
#
#   # module.cloud_run_storybook.data.google_iam_policy.cloud_run_policy will be read during apply
#   # (depends on a resource or a module with changes pending)
#  <= data "google_iam_policy" "cloud_run_policy" {
#       + id          = (known after apply)
#       + policy_data = (known after apply)
#
#       + binding {
#           + members = [
#               + "allUsers",
#             ]
#           + role    = "roles/run.invoker"
#         }
#       + binding {
#           + members = [
#               + "serviceAccount:dev-storybook-service-sa@fs-microservices.iam.gserviceaccount.com",
#             ]
#           + role    = "roles/run.admin"
#         }
#     }
#
#   # module.cloud_run_storybook.google_cloud_run_service.service will be created
#   + resource "google_cloud_run_service" "service" {
#       + autogenerate_revision_name = false
#       + id                         = (known after apply)
#       + location                   = "us-central1"
#       + name                       = "dev-storybook-service"
#       + project                    = "fs-microservices"
#       + status                     = (known after apply)
#
#       + template {
#           + metadata {
#               + annotations      = {
#                   + "autoscaling.knative.dev/maxScale"        = "10"
#                   + "autoscaling.knative.dev/minScale"        = "0"
#                   + "run.googleapis.com/vpc-access-connector" = "dev-connector"
#                   + "run.googleapis.com/vpc-access-egress"    = "all-traffic"
#                 }
#               + generation       = (known after apply)
#               + labels           = (known after apply)
#               + name             = (known after apply)
#               + namespace        = (known after apply)
#               + resource_version = (known after apply)
#               + self_link        = (known after apply)
#               + uid              = (known after apply)
#             }
#           + spec {
#               + container_concurrency = (known after apply)
#               + service_account_name  = "dev-storybook-service-sa@fs-microservices.iam.gserviceaccount.com"
#               + serving_state         = (known after apply)
#               + timeout_seconds       = (known after apply)
#
#               + containers {
#                   + image = "us-central1-docker.pkg.dev/fs-microservices/dev-repo/dev-storybook-service:latest"
#                   + name  = (known after apply)
#
#                   + env {
#                       + name  = "NODE_ENV"
#                       + value = "dev"
#                     }
#                 }
#             }
#         }
#
#       + traffic {
#           + latest_revision = true
#           + percent         = 100
#           + url             = (known after apply)
#         }
#     }
#
#   # module.cloud_run_storybook.google_cloud_run_service_iam_policy.app_service_iam will be created
#   + resource "google_cloud_run_service_iam_policy" "app_service_iam" {
#       + etag        = (known after apply)
#       + id          = (known after apply)
#       + location    = "us-central1"
#       + policy_data = (known after apply)
#       + project     = "fs-microservices"
#       + service     = "dev-storybook-service"
#     }
#
#   # module.cloud_run_storybook.google_compute_region_network_endpoint_group.cloudrun_neg will be created
#   + resource "google_compute_region_network_endpoint_group" "cloudrun_neg" {
#       + id                    = (known after apply)
#       + name                  = "dev-storybook-service-neg"
#       + network_endpoint_type = "SERVERLESS"
#       + project               = "fs-microservices"
#       + region                = "us-central1"
#       + self_link             = (known after apply)
#
#       + cloud_run {
#           + service = "dev-storybook-service"
#         }
#     }
#
#   # module.cloud_run_web.data.google_iam_policy.cloud_run_policy will be read during apply
#   # (config refers to values not yet known)
#  <= data "google_iam_policy" "cloud_run_policy" {
#       + id          = (known after apply)
#       + policy_data = (known after apply)
#
#       + binding {
#           + members = [
#               + "allUsers",
#             ]
#           + role    = "roles/run.invoker"
#         }
#       + binding {
#           + members = [
#               + (known after apply),
#             ]
#           + role    = "roles/run.admin"
#         }
#     }
#
#   # module.cloud_run_web.google_cloud_run_service.service will be created
#   + resource "google_cloud_run_service" "service" {
#       + autogenerate_revision_name = false
#       + id                         = (known after apply)
#       + location                   = "us-central1"
#       + name                       = "dev-web-service"
#       + project                    = "fs-microservices"
#       + status                     = (known after apply)
#
#       + template {
#           + metadata {
#               + annotations      = {
#                   + "autoscaling.knative.dev/maxScale"        = "10"
#                   + "autoscaling.knative.dev/minScale"        = "0"
#                   + "run.googleapis.com/vpc-access-connector" = "dev-connector"
#                   + "run.googleapis.com/vpc-access-egress"    = "all-traffic"
#                 }
#               + generation       = (known after apply)
#               + labels           = (known after apply)
#               + name             = (known after apply)
#               + namespace        = (known after apply)
#               + resource_version = (known after apply)
#               + self_link        = (known after apply)
#               + uid              = (known after apply)
#             }
#           + spec {
#               + container_concurrency = (known after apply)
#               + service_account_name  = (known after apply)
#               + serving_state         = (known after apply)
#               + timeout_seconds       = (known after apply)
#
#               + containers {
#                   + image = "us-central1-docker.pkg.dev/fs-microservices/dev-repo/dev-web-service:latest"
#                   + name  = (known after apply)
#
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                 }
#             }
#         }
#
#       + traffic {
#           + latest_revision = true
#           + percent         = 100
#           + url             = (known after apply)
#         }
#     }
#
#   # module.cloud_run_web.google_cloud_run_service_iam_policy.app_service_iam will be created
#   + resource "google_cloud_run_service_iam_policy" "app_service_iam" {
#       + etag        = (known after apply)
#       + id          = (known after apply)
#       + location    = "us-central1"
#       + policy_data = (known after apply)
#       + project     = "fs-microservices"
#       + service     = "dev-web-service"
#     }
#
#   # module.cloud_run_web.google_compute_region_network_endpoint_group.cloudrun_neg will be created
#   + resource "google_compute_region_network_endpoint_group" "cloudrun_neg" {
#       + id                    = (known after apply)
#       + name                  = "dev-web-service-neg"
#       + network_endpoint_type = "SERVERLESS"
#       + project               = "fs-microservices"
#       + region                = "us-central1"
#       + self_link             = (known after apply)
#
#       + cloud_run {
#           + service = "dev-web-service"
#         }
#     }
#
#   # module.cloud_run_web.google_project_iam_member.cloud_run_sa_secret_manager_permissions will be created
#   + resource "google_project_iam_member" "cloud_run_sa_secret_manager_permissions" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "fs-microservices"
#       + role    = "roles/secretmanager.secretAccessor"
#     }
#
#   # module.cloud_run_web.google_service_account.cloud_run_sa will be created
#   + resource "google_service_account" "cloud_run_sa" {
#       + account_id   = "dev-web-service-sa"
#       + disabled     = false
#       + display_name = "Service Account for web-service Cloud Run Service"
#       + email        = (known after apply)
#       + id           = (known after apply)
#       + member       = (known after apply)
#       + name         = (known after apply)
#       + project      = "fs-microservices"
#       + unique_id    = (known after apply)
#     }
#
#   # module.cloud_sql.data.google_compute_default_service_account.default will be read during apply
#   # (depends on a resource or a module with changes pending)
#  <= data "google_compute_default_service_account" "default" {
#       + display_name = (known after apply)
#       + email        = (known after apply)
#       + id           = (known after apply)
#       + member       = (known after apply)
#       + name         = (known after apply)
#       + project      = "fs-microservices"
#       + unique_id    = (known after apply)
#     }
#
#   # module.cloud_sql.data.google_secret_manager_secret_version.db_passwords["auth"] will be read during apply
#   # (depends on a resource or a module with changes pending)
#  <= data "google_secret_manager_secret_version" "db_passwords" {
#       + create_time  = (known after apply)
#       + destroy_time = (known after apply)
#       + enabled      = (known after apply)
#       + id           = (known after apply)
#       + name         = (known after apply)
#       + project      = "fs-microservices"
#       + secret       = "dev-auth-db-password"
#       + secret_data  = (sensitive value)
#       + version      = (known after apply)
#     }
#
#   # module.cloud_sql.data.google_secret_manager_secret_version.db_passwords["events"] will be read during apply
#   # (depends on a resource or a module with changes pending)
#  <= data "google_secret_manager_secret_version" "db_passwords" {
#       + create_time  = (known after apply)
#       + destroy_time = (known after apply)
#       + enabled      = (known after apply)
#       + id           = (known after apply)
#       + name         = (known after apply)
#       + project      = "fs-microservices"
#       + secret       = "dev-events-db-password"
#       + secret_data  = (sensitive value)
#       + version      = (known after apply)
#     }
#
#   # module.cloud_sql.data.google_secret_manager_secret_version.db_usernames["auth"] will be read during apply
#   # (depends on a resource or a module with changes pending)
#  <= data "google_secret_manager_secret_version" "db_usernames" {
#       + create_time  = (known after apply)
#       + destroy_time = (known after apply)
#       + enabled      = (known after apply)
#       + id           = (known after apply)
#       + name         = (known after apply)
#       + project      = "fs-microservices"
#       + secret       = "dev-auth-db-user"
#       + secret_data  = (sensitive value)
#       + version      = (known after apply)
#     }
#
#   # module.cloud_sql.data.google_secret_manager_secret_version.db_usernames["events"] will be read during apply
#   # (depends on a resource or a module with changes pending)
#  <= data "google_secret_manager_secret_version" "db_usernames" {
#       + create_time  = (known after apply)
#       + destroy_time = (known after apply)
#       + enabled      = (known after apply)
#       + id           = (known after apply)
#       + name         = (known after apply)
#       + project      = "fs-microservices"
#       + secret       = "dev-events-db-user"
#       + secret_data  = (sensitive value)
#       + version      = (known after apply)
#     }
#
#   # module.cloud_sql.google_project_iam_member.default_sa_cloudsql_client_permissions will be created
#   + resource "google_project_iam_member" "default_sa_cloudsql_client_permissions" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "fs-microservices"
#       + role    = "roles/cloudsql.client"
#     }
#
#   # module.cloud_sql.google_project_iam_member.default_sa_secret_manager_permissions will be created
#   + resource "google_project_iam_member" "default_sa_secret_manager_permissions" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "fs-microservices"
#       + role    = "roles/secretmanager.secretAccessor"
#     }
#
#   # module.cloud_sql.google_sql_database.databases["auth"] will be created
#   + resource "google_sql_database" "databases" {
#       + charset         = (known after apply)
#       + collation       = (known after apply)
#       + deletion_policy = "DELETE"
#       + id              = (known after apply)
#       + instance        = "dev-db-instance"
#       + name            = "auth_db"
#       + project         = "fs-microservices"
#       + self_link       = (known after apply)
#     }
#
#   # module.cloud_sql.google_sql_database.databases["events"] will be created
#   + resource "google_sql_database" "databases" {
#       + charset         = (known after apply)
#       + collation       = (known after apply)
#       + deletion_policy = "DELETE"
#       + id              = (known after apply)
#       + instance        = "dev-db-instance"
#       + name            = "events_db"
#       + project         = "fs-microservices"
#       + self_link       = (known after apply)
#     }
#
#   # module.cloud_sql.google_sql_database_instance.postgres_instance will be created
#   + resource "google_sql_database_instance" "postgres_instance" {
#       + available_maintenance_versions = (known after apply)
#       + connection_name                = (known after apply)
#       + database_version               = "POSTGRES_14"
#       + deletion_protection            = false
#       + dns_name                       = (known after apply)
#       + encryption_key_name            = (known after apply)
#       + first_ip_address               = (known after apply)
#       + id                             = (known after apply)
#       + instance_type                  = (known after apply)
#       + ip_address                     = (known after apply)
#       + maintenance_version            = (known after apply)
#       + master_instance_name           = (known after apply)
#       + name                           = "dev-db-instance"
#       + private_ip_address             = (known after apply)
#       + project                        = "fs-microservices"
#       + psc_service_attachment_link    = (known after apply)
#       + public_ip_address              = (known after apply)
#       + region                         = "us-central1"
#       + self_link                      = (known after apply)
#       + server_ca_cert                 = (sensitive value)
#       + service_account_email_address  = (known after apply)
#
#       + settings {
#           + activation_policy     = "ALWAYS"
#           + availability_type     = "ZONAL"
#           + connector_enforcement = (known after apply)
#           + disk_autoresize       = true
#           + disk_autoresize_limit = 0
#           + disk_size             = (known after apply)
#           + disk_type             = "PD_SSD"
#           + edition               = "ENTERPRISE"
#           + pricing_plan          = "PER_USE"
#           + tier                  = "db-f1-micro"
#           + user_labels           = {
#               + "environment" = "dev"
#             }
#           + version               = (known after apply)
#
#           + ip_configuration {
#               + ipv4_enabled    = false
#               + private_network = "https://www.googleapis.com/compute/v1/projects/fs-microservices/global/networks/dev-vpc"
#               + ssl_mode        = (known after apply)
#
#               + authorized_networks {
#                   + name  = "home-network-1"
#                   + value = "86.49.224.158/32"
#                 }
#             }
#         }
#     }
#
#   # module.cloud_sql.google_sql_user.database_users["auth"] will be created
#   + resource "google_sql_user" "database_users" {
#       + host                    = (known after apply)
#       + id                      = (known after apply)
#       + instance                = "dev-db-instance"
#       + name                    = (sensitive value)
#       + password                = (sensitive value)
#       + project                 = "fs-microservices"
#       + sql_server_user_details = (known after apply)
#     }
#
#   # module.cloud_sql.google_sql_user.database_users["events"] will be created
#   + resource "google_sql_user" "database_users" {
#       + host                    = (known after apply)
#       + id                      = (known after apply)
#       + instance                = "dev-db-instance"
#       + name                    = (sensitive value)
#       + password                = (sensitive value)
#       + project                 = "fs-microservices"
#       + sql_server_user_details = (known after apply)
#     }
#
#   # module.rabbitmq.data.google_compute_default_service_account.default will be read during apply
#   # (depends on a resource or a module with changes pending)
#  <= data "google_compute_default_service_account" "default" {
#       + display_name = (known after apply)
#       + email        = (known after apply)
#       + id           = (known after apply)
#       + member       = (known after apply)
#       + name         = (known after apply)
#       + project      = (known after apply)
#       + unique_id    = (known after apply)
#     }
#
#   # module.rabbitmq.google_project_iam_member.iap_tunnel_user will be created
#   + resource "google_project_iam_member" "iap_tunnel_user" {
#       + etag    = (known after apply)
#       + id      = (known after apply)
#       + member  = (known after apply)
#       + project = "fs-microservices"
#       + role    = "roles/iap.tunnelResourceAccessor"
#     }
#
#   # module.vpc.google_service_networking_connection.private_vpc_connection["projects/fs-microservices/global/networks/dev-vpc"] will be created
#   + resource "google_service_networking_connection" "private_vpc_connection" {
#       + id                      = (known after apply)
#       + network                 = "projects/fs-microservices/global/networks/dev-vpc"
#       + peering                 = (known after apply)
#       + reserved_peering_ranges = [
#           + "dev-private-ip",
#         ]
#       + service                 = "servicenetworking.googleapis.com"
#     }
#
# Plan: 34 to add, 0 to change, 0 to destroy.
# module.vpc.google_service_networking_connection.private_vpc_connection["projects/fs-microservices/global/networks/dev-vpc"]: Creating...
# module.vpc.google_service_networking_connection.private_vpc_connection["projects/fs-microservices/global/networks/dev-vpc"]: Still creating... [10s elapsed]
# module.vpc.google_service_networking_connection.private_vpc_connection["projects/fs-microservices/global/networks/dev-vpc"]: Still creating... [20s elapsed]
# module.vpc.google_service_networking_connection.private_vpc_connection["projects/fs-microservices/global/networks/dev-vpc"]: Still creating... [30s elapsed]
# module.vpc.google_service_networking_connection.private_vpc_connection["projects/fs-microservices/global/networks/dev-vpc"]: Still creating... [40s elapsed]
# module.vpc.google_service_networking_connection.private_vpc_connection["projects/fs-microservices/global/networks/dev-vpc"]: Still creating... [50s elapsed]
# module.vpc.google_service_networking_connection.private_vpc_connection["projects/fs-microservices/global/networks/dev-vpc"]: Still creating... 0s elapsed]
# module.vpc.google_service_networking_connection.private_vpc_connection["projects/fs-microservices/global/networks/dev-vpc"]: Creation complete after 1m4s [id=projects%2Ffs-microservices%2Fglobal%2Fnetworks%2Fdev-vpc:servicenetworking.googleapis.com]
# module.cloud_sql.data.google_compute_default_service_account.default: Reading...
# module.rabbitmq.data.google_compute_default_service_account.default: Reading...
# module.cloud_sql.data.google_secret_manager_secret_version.db_usernames["events"]: Reading...
# module.cloud_sql.data.google_secret_manager_secret_version.db_passwords["events"]: Reading...
# module.cloud_sql.data.google_secret_manager_secret_version.db_passwords["auth"]: Reading...
# module.cloud_sql.data.google_secret_manager_secret_version.db_usernames["auth"]: Reading...
# module.cloud_run_storybook.data.google_iam_policy.cloud_run_policy: Reading...
# module.cloud_run_storybook.data.google_iam_policy.cloud_run_policy: Read complete after 0s [id=739928917]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Creating...
# module.cloud_run_storybook.google_cloud_run_service.service: Creating...
# module.cloud_sql.data.google_secret_manager_secret_version.db_usernames["auth"]: Read complete after 1s [id=projects/526101498496/secrets/dev-auth-db-user/versions/1]
# module.cloud_sql.data.google_secret_manager_secret_version.db_passwords["auth"]: Read complete after 1s [id=projects/526101498496/secrets/dev-auth-db-password/versions/1]
# module.cloud_sql.data.google_secret_manager_secret_version.db_usernames["events"]: Read complete after 1s [id=projects/526101498496/secrets/dev-events-db-user/versions/1]
# module.cloud_sql.data.google_secret_manager_secret_version.db_passwords["events"]: Read complete after 1s [id=projects/526101498496/secrets/dev-events-db-password/versions/1]
# module.rabbitmq.data.google_compute_default_service_account.default: Read complete after 1s [id=projects/fs-microservices/serviceAccounts/526101498496-compute@developer.gserviceaccount.com]
# module.rabbitmq.google_project_iam_member.iap_tunnel_user: Creating...
# module.cloud_sql.data.google_compute_default_service_account.default: Read complete after 1s [id=projects/fs-microservices/serviceAccounts/526101498496-compute@developer.gserviceaccount.com]
# module.cloud_sql.google_project_iam_member.default_sa_cloudsql_client_permissions: Creating...
# module.cloud_sql.google_project_iam_member.default_sa_secret_manager_permissions: Creating...
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... [10s elapsed]
# module.cloud_sql.google_project_iam_member.default_sa_secret_manager_permissions: Creation complete after 9s [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:526101498496-compute@developer.gserviceaccount.com]
# module.rabbitmq.google_project_iam_member.iap_tunnel_user: Creation complete after 10s [id=fs-microservices/roles/iap.tunnelResourceAccessor/serviceAccount:526101498496-compute@developer.gserviceaccount.com]
# module.cloud_sql.google_project_iam_member.default_sa_cloudsql_client_permissions: Creation complete after 10s [id=fs-microservices/roles/cloudsql.client/serviceAccount:526101498496-compute@developer.gserviceaccount.com]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... [20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... [30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... [40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... [50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 40s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 50s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 0s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 10s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 20s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Still creating... 30s elapsed]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Creation complete after 12m38s [id=dev-db-instance]
# module.cloud_sql.google_sql_database.databases["auth"]: Creating...
# module.cloud_sql.google_sql_database.databases["events"]: Creating...
# module.cloud_sql.google_sql_user.database_users["events"]: Creating...
# module.cloud_sql.google_sql_user.database_users["auth"]: Creating...
# module.cloud_sql.google_sql_database.databases["auth"]: Creation complete after 7s [id=projects/fs-microservices/instances/dev-db-instance/databases/auth_db]
# module.cloud_sql.google_sql_user.database_users["events"]: Still creating... [10s elapsed]
# module.cloud_sql.google_sql_database.databases["events"]: Still creating... [10s elapsed]
# module.cloud_sql.google_sql_user.database_users["auth"]: Still creating... [10s elapsed]
# module.cloud_sql.google_sql_database.databases["events"]: Creation complete after 10s [id=projects/fs-microservices/instances/dev-db-instance/databases/events_db]
# module.cloud_sql.google_sql_user.database_users["events"]: Creation complete after 17s [id=events_user//dev-db-instance]
# module.cloud_sql.google_sql_user.database_users["auth"]: Still creating... [20s elapsed]
# module.cloud_sql.google_sql_user.database_users["auth"]: Creation complete after 21s [id=auth_user//dev-db-instance]
# module.cloud_run_auth.google_service_account.cloud_run_sa: Creating...
# module.cloud_run_events.google_service_account.cloud_run_sa: Creating...
# module.cloud_run_auth.google_service_account.cloud_run_sa: Creation complete after 3s [id=projects/fs-microservices/serviceAccounts/dev-auth-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_auth.data.google_iam_policy.cloud_run_policy: Reading...
# module.cloud_run_auth.google_project_iam_member.cloud_run_sa_sql_client_permissions[0]: Creating...
# module.cloud_run_auth.google_project_iam_member.cloud_run_sa_secret_manager_permissions: Creating...
# module.cloud_run_auth.data.google_iam_policy.cloud_run_policy: Read complete after 0s [id=580184311]
# module.cloud_run_events.google_service_account.cloud_run_sa: Creation complete after 3s [id=projects/fs-microservices/serviceAccounts/dev-events-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_events.data.google_iam_policy.cloud_run_policy: Reading...
# module.cloud_run_events.google_project_iam_member.cloud_run_sa_secret_manager_permissions: Creating...
# module.cloud_run_events.google_project_iam_member.cloud_run_sa_sql_client_permissions[0]: Creating...
# module.cloud_run_events.data.google_iam_policy.cloud_run_policy: Read complete after 0s [id=3535090946]
# module.cloud_run_auth.google_project_iam_member.cloud_run_sa_secret_manager_permissions: Still creating... [10s elapsed]
# module.cloud_run_auth.google_project_iam_member.cloud_run_sa_sql_client_permissions[0]: Still creating... [10s elapsed]
# module.cloud_run_events.google_project_iam_member.cloud_run_sa_secret_manager_permissions: Creation complete after 10s [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:dev-events-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_events.google_project_iam_member.cloud_run_sa_sql_client_permissions[0]: Still creating... [10s elapsed]
# module.cloud_run_auth.google_project_iam_member.cloud_run_sa_secret_manager_permissions: Creation complete after 10s [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:dev-auth-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_auth.google_project_iam_member.cloud_run_sa_sql_client_permissions[0]: Creation complete after 11s [id=fs-microservices/roles/cloudsql.client/serviceAccount:dev-auth-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_auth.google_cloud_run_service.service: Creating...
# module.cloud_run_events.google_project_iam_member.cloud_run_sa_sql_client_permissions[0]: Creation complete after 11s [id=fs-microservices/roles/cloudsql.client/serviceAccount:dev-events-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_events.google_cloud_run_service.service: Creating...
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... [10s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... [20s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... [30s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... [40s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... [50s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 0s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 10s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 20s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 30s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 40s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 50s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 0s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 10s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 20s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 30s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 40s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 50s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 0s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 10s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 20s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 30s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 40s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 50s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 0s elapsed]
# module.cloud_run_auth.google_cloud_run_service.service: Still creating... 10s elapsed]
# ╷
# │ Warning: Value for undeclared variable
# │
# │ The root module does not declare a variable named "bucket_name" but a value
# │ was found in file "terraform.tfvars". If you meant to use this value, add a
# │ "variable" block to the configuration.
# │
# │ To silence these warnings, use TF_VAR_... environment variables to provide
# │ certain "global" settings to all configurations in your organization. To
# │ reduce the verbosity of these warnings, use the -compact-warnings option.
# ╵
# ╷
# │ Warning: Value for undeclared variable
# │
# │ The root module does not declare a variable named "project_name" but a value
# │ was found in file "terraform.tfvars". If you meant to use this value, add a
# │ "variable" block to the configuration.
# │
# │ To silence these warnings, use TF_VAR_... environment variables to provide
# │ certain "global" settings to all configurations in your organization. To
# │ reduce the verbosity of these warnings, use the -compact-warnings option.
# ╵
# ╷
# │ Error: Error waiting to create Service: resource is in failed state "Ready:False", message: Revision 'dev-events-service-00001-gcx' is not ready and cannot serve traffic. Image 'us-central1-docker.pkg.dev/fs-microservices/dev-repo/dev-events-service:latest' not found.
# │
# │   with module.cloud_run_events.google_cloud_run_service.service,
# │   on ../../modules/cloud_run/main.tf line 91, in resource "google_cloud_run_service" "service":
# │   91: resource "google_cloud_run_service" "service" {
# │
# ╵
# ╷
# │ Error: Error waiting to create Service: resource is in failed state "Ready:False", message: Revision 'dev-auth-service-00001-55d' is not ready and cannot serve traffic. The user-provided container failed to start and listen on the port defined provided by the PORT=8080 environment variable. Logs for this revision might contain more information.
# │
# │ Logs URL: https://console.cloud.google.com/logs/viewer?project=fs-microservices&resource=cloud_run_revision/service_name/dev-auth-service/revision_name/dev-auth-service-00001-55d&advancedFilter=resource.type%3D%22cloud_run_revision%22%0Aresource.labels.service_name%3D%22dev-auth-service%22%0Aresource.labels.revision_name%3D%22dev-auth-service-00001-55d%22
# │ For more troubleshooting guidance, see https://cloud.google.com/run/docs/troubleshooting#container-failed-to-start
# │
# │   with module.cloud_run_auth.google_cloud_run_service.service,
# │   on ../../modules/cloud_run/main.tf line 91, in resource "google_cloud_run_service" "service":
# │   91: resource "google_cloud_run_service" "service" {
# │
# ╵
# ╷
# │ Error: Error waiting to create Service: resource is in failed state "Ready:False", message: Revision 'dev-storybook-service-00001-j68' is not ready and cannot serve traffic. Image 'us-central1-docker.pkg.dev/fs-microservices/dev-repo/dev-storybook-service:latest' not found.
# │
# │   with module.cloud_run_storybook.google_cloud_run_service.service,
# │   on ../../modules/cloud_run/main.tf line 91, in resource "google_cloud_run_service" "service":
# │   91: resource "google_cloud_run_service" "service" {
# │
# ╵
