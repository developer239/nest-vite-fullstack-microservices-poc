# %% [markdown]
# # Terraform Deployment

# %% [markdown]
# Initialize local variables from the shared project variables file.

# %%
from project_vars import project_variables

env = project_variables['environment']

# %% [markdown]
# We need to change the current working directory to the `environments/{env}` folder so that terraform commands can be executed in the correct directory.

# %%
import os

os.chdir(f"./environments/{env}")
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /Users/michaljarnot/IdeaProjects/nest-microservices-example-v2/infra/environments/dev

# %% [markdown]
# Initialize the terraform workspace.

# %%
# !terraform init
# Out:
# Initializing the backend...
# Initializing modules...
#
# Initializing provider plugins...
# - Reusing previous version of hashicorp/google from the dependency lock file
# - Reusing previous version of hashicorp/google-beta from the dependency lock file
# - Using previously-installed hashicorp/google v5.19.0
# - Using previously-installed hashicorp/google-beta v5.38.0
#
# Terraform has been successfully initialized!
#
# You may now begin working with Terraform. Try running "terraform plan" to see
# any changes that are required for your infrastructure. All Terraform commands
# should now work.
#
# If you ever set or change modules or backend configuration for Terraform,
# rerun this command to reinitialize your working directory. If you forget, other
# commands will detect it and remind you to do so if necessary.

# %% [markdown]
# Apply the terraform changes.

# %%
# !terraform plan
# Out:
# Acquiring state lock. This may take a few moments...
# module.firebase.google_project_service.firebase_api: Refreshing state... [id=fs-microservices/firebase.googleapis.com]
# module.vpc.google_compute_network.vpc: Refreshing state... [id=projects/fs-microservices/global/networks/dev-vpc]
# module.ci_cd_service_account.google_service_account.ci_cd: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com]
# module.artifact_registry.google_artifact_registry_repository.docker_repository: Refreshing state... [id=projects/fs-microservices/locations/us-central1/repositories/dev-repo]
# module.ci_cd_service_account.google_secret_manager_secret.ci_cd_key_secret: Refreshing state... [id=projects/fs-microservices/secrets/dev-gcp-auth-sa-key]
# module.vpc.google_compute_global_address.private_ip_address: Refreshing state... [id=projects/fs-microservices/global/addresses/dev-private-ip]
# module.vpc.google_compute_router.router[0]: Refreshing state... [id=projects/fs-microservices/regions/us-central1/routers/dev-router]
# module.vpc.google_compute_firewall.allow_internal: Refreshing state... [id=projects/fs-microservices/global/firewalls/dev-allow-internal]
# module.vpc.google_compute_subnetwork.subnet: Refreshing state... [id=projects/fs-microservices/regions/us-central1/subnetworks/dev-subnet]
# module.vpc.google_compute_firewall.allow_iap_ssh: Refreshing state... [id=projects/fs-microservices/global/firewalls/dev-allow-iap-ssh]
# module.vpc.google_compute_firewall.allow_egress: Refreshing state... [id=projects/fs-microservices/global/firewalls/dev-allow-egress]
# module.ci_cd_service_account.google_project_iam_member.ci_cd_sa_permissions["roles/secretmanager.secretAccessor"]: Refreshing state... [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com]
# module.ci_cd_service_account.google_project_iam_member.ci_cd_sa_permissions["roles/cloudsql.client"]: Refreshing state... [id=fs-microservices/roles/cloudsql.client/serviceAccount:dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com]
# module.ci_cd_service_account.google_project_iam_member.ci_cd_sa_permissions["roles/editor"]: Refreshing state... [id=fs-microservices/roles/editor/serviceAccount:dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com]
# module.ci_cd_service_account.google_service_account_key.ci_cd_key: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com/keys/377e67e60f2f29e5d1d14d7d52fd8226938646a1]
# module.vpc.google_service_networking_connection.private_vpc_connection["projects/fs-microservices/global/networks/dev-vpc"]: Refreshing state... [id=projects%2Ffs-microservices%2Fglobal%2Fnetworks%2Fdev-vpc:servicenetworking.googleapis.com]
# module.ci_cd_service_account.google_secret_manager_secret_version.ci_cd_key_secret_version: Refreshing state... [id=projects/526101498496/secrets/dev-gcp-auth-sa-key/versions/1]
# module.vpc.google_vpc_access_connector.connector: Refreshing state... [id=projects/fs-microservices/locations/us-central1/connectors/dev-connector]
# module.vpc.google_compute_router_nat.nat[0]: Refreshing state... [id=fs-microservices/us-central1/dev-router/dev-nat]
# module.rabbitmq.google_service_account.rabbitmq_sa: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-rabbitmq-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_sql.data.google_secret_manager_secret_version.db_passwords["events"]: Reading...
# module.cloud_sql.google_compute_global_address.private_ip_address: Refreshing state... [id=projects/fs-microservices/global/addresses/dev-db-private-ip]
# module.rabbitmq.data.google_compute_default_service_account.default: Reading...
# module.cloud_sql.data.google_secret_manager_secret_version.db_passwords["auth"]: Reading...
# module.cloud_sql.data.google_compute_default_service_account.default: Reading...
# module.cloud_sql.data.google_secret_manager_secret_version.db_usernames["auth"]: Reading...
# module.cloud_sql.data.google_secret_manager_secret_version.db_usernames["events"]: Reading...
# module.cloud_run_storybook.google_service_account.cloud_run_sa: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-storybook-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Refreshing state... [id=dev-db-instance]
# module.cloud_sql.data.google_secret_manager_secret_version.db_usernames["auth"]: Read complete after 1s [id=projects/526101498496/secrets/dev-auth-db-user/versions/1]
# module.rabbitmq.google_project_iam_member.rabbitmq_sa_permissions["roles/artifactregistry.reader"]: Refreshing state... [id=fs-microservices/roles/artifactregistry.reader/serviceAccount:dev-rabbitmq-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_sql.data.google_secret_manager_secret_version.db_passwords["auth"]: Read complete after 1s [id=projects/526101498496/secrets/dev-auth-db-password/versions/1]
# module.cloud_sql.data.google_secret_manager_secret_version.db_passwords["events"]: Read complete after 1s [id=projects/526101498496/secrets/dev-events-db-password/versions/1]
# module.rabbitmq.google_project_iam_member.rabbitmq_sa_permissions["roles/monitoring.metricWriter"]: Refreshing state... [id=fs-microservices/roles/monitoring.metricWriter/serviceAccount:dev-rabbitmq-sa@fs-microservices.iam.gserviceaccount.com]
# module.rabbitmq.google_project_iam_member.rabbitmq_sa_permissions["roles/logging.logWriter"]: Refreshing state... [id=fs-microservices/roles/logging.logWriter/serviceAccount:dev-rabbitmq-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_sql.data.google_secret_manager_secret_version.db_usernames["events"]: Read complete after 1s [id=projects/526101498496/secrets/dev-events-db-user/versions/1]
# module.cloud_sql.google_sql_database.databases["auth"]: Refreshing state... [id=projects/fs-microservices/instances/dev-db-instance/databases/auth_db]
# module.cloud_sql.google_sql_database.databases["events"]: Refreshing state... [id=projects/fs-microservices/instances/dev-db-instance/databases/events_db]
# module.cloud_sql.google_sql_user.database_users["events"]: Refreshing state... [id=events_user//dev-db-instance]
# module.cloud_sql.google_sql_user.database_users["auth"]: Refreshing state... [id=auth_user//dev-db-instance]
# module.rabbitmq.data.google_compute_default_service_account.default: Read complete after 1s [id=projects/fs-microservices/serviceAccounts/526101498496-compute@developer.gserviceaccount.com]
# module.rabbitmq.google_project_iam_member.iap_tunnel_user: Refreshing state... [id=fs-microservices/roles/iap.tunnelResourceAccessor/serviceAccount:526101498496-compute@developer.gserviceaccount.com]
# module.cloud_run_storybook.google_project_iam_member.cloud_run_sa_secret_manager_permissions: Refreshing state... [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:dev-storybook-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_sql.data.google_compute_default_service_account.default: Read complete after 1s [id=projects/fs-microservices/serviceAccounts/526101498496-compute@developer.gserviceaccount.com]
# module.cloud_run_storybook.data.google_iam_policy.cloud_run_policy: Reading...
# module.cloud_run_storybook.data.google_iam_policy.cloud_run_policy: Read complete after 0s [id=739928917]
# module.cloud_sql.google_project_iam_member.default_sa_cloudsql_client_permissions: Refreshing state... [id=fs-microservices/roles/cloudsql.client/serviceAccount:526101498496-compute@developer.gserviceaccount.com]
# module.cloud_sql.google_project_iam_member.default_sa_secret_manager_permissions: Refreshing state... [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:526101498496-compute@developer.gserviceaccount.com]
# module.rabbitmq.google_compute_instance.rabbitmq: Refreshing state... [id=projects/fs-microservices/zones/us-central1-a/instances/dev-rabbitmq]
# module.rabbitmq.google_compute_firewall.rabbitmq: Refreshing state... [id=projects/fs-microservices/global/firewalls/dev-rabbitmq-allow]
# module.cloud_run_storybook.google_cloud_run_service.service: Refreshing state... [id=locations/us-central1/namespaces/fs-microservices/services/dev-storybook-service]
# module.cloud_run_storybook.google_cloud_run_service_iam_policy.app_service_iam: Refreshing state... [id=v1/projects/fs-microservices/locations/us-central1/services/dev-storybook-service]
# module.cloud_run_storybook.google_compute_region_network_endpoint_group.cloudrun_neg: Refreshing state... [id=projects/fs-microservices/regions/us-central1/networkEndpointGroups/dev-storybook-service-neg]
# module.cloud_run_events.google_service_account.cloud_run_sa: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-events-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_auth.google_service_account.cloud_run_sa: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-auth-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.firebase.google_firebase_project.default: Refreshing state... [id=projects/fs-microservices]
# module.cloud_run_events.google_project_iam_member.cloud_run_sa_secret_manager_permissions: Refreshing state... [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:dev-events-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_events.google_project_iam_member.cloud_run_sa_sql_client_permissions[0]: Refreshing state... [id=fs-microservices/roles/cloudsql.client/serviceAccount:dev-events-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_events.data.google_iam_policy.cloud_run_policy: Reading...
# module.cloud_run_events.data.google_iam_policy.cloud_run_policy: Read complete after 0s [id=3535090946]
# module.cloud_run_auth.google_project_iam_member.cloud_run_sa_secret_manager_permissions: Refreshing state... [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:dev-auth-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_auth.google_project_iam_member.cloud_run_sa_sql_client_permissions[0]: Refreshing state... [id=fs-microservices/roles/cloudsql.client/serviceAccount:dev-auth-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_auth.data.google_iam_policy.cloud_run_policy: Reading...
# module.cloud_run_auth.data.google_iam_policy.cloud_run_policy: Read complete after 0s [id=580184311]
# module.firebase.google_firebase_web_app.env_specific: Refreshing state... [id=projects/fs-microservices/webApps/1:526101498496:web:783a17bb109c49413f3465]
# module.firebase.data.google_firebase_web_app_config.env_specific: Reading...
# module.cloud_run_events.google_cloud_run_service.service: Refreshing state... [id=locations/us-central1/namespaces/fs-microservices/services/dev-events-service]
# module.cloud_run_events.google_cloud_run_service_iam_policy.app_service_iam: Refreshing state... [id=v1/projects/fs-microservices/locations/us-central1/services/dev-events-service]
# module.cloud_run_events.google_compute_region_network_endpoint_group.cloudrun_neg: Refreshing state... [id=projects/fs-microservices/regions/us-central1/networkEndpointGroups/dev-events-service-neg]
# module.firebase.data.google_firebase_web_app_config.env_specific: Read complete after 1s [id=1:526101498496:web:783a17bb109c49413f3465]
# module.cloud_run_auth.google_cloud_run_service.service: Refreshing state... [id=locations/us-central1/namespaces/fs-microservices/services/dev-auth-service]
# module.cloud_run_auth.google_cloud_run_service_iam_policy.app_service_iam: Refreshing state... [id=v1/projects/fs-microservices/locations/us-central1/services/dev-auth-service]
# module.cloud_run_auth.google_compute_region_network_endpoint_group.cloudrun_neg: Refreshing state... [id=projects/fs-microservices/regions/us-central1/networkEndpointGroups/dev-auth-service-neg]
# module.cloud_run_gateway.google_service_account.cloud_run_sa: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-gateway-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_gateway.google_project_iam_member.cloud_run_sa_secret_manager_permissions: Refreshing state... [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:dev-gateway-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_gateway.data.google_iam_policy.cloud_run_policy: Reading...
# module.cloud_run_gateway.data.google_iam_policy.cloud_run_policy: Read complete after 0s [id=2670789318]
# module.cloud_run_gateway.google_cloud_run_service.service: Refreshing state... [id=locations/us-central1/namespaces/fs-microservices/services/dev-gateway-service]
# module.cloud_run_gateway.google_cloud_run_service_iam_policy.app_service_iam: Refreshing state... [id=v1/projects/fs-microservices/locations/us-central1/services/dev-gateway-service]
# module.cloud_run_gateway.google_compute_region_network_endpoint_group.cloudrun_neg: Refreshing state... [id=projects/fs-microservices/regions/us-central1/networkEndpointGroups/dev-gateway-service-neg]
# module.cloud_run_web.google_service_account.cloud_run_sa: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-web-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_web.google_project_iam_member.cloud_run_sa_secret_manager_permissions: Refreshing state... [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:dev-web-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_web.data.google_iam_policy.cloud_run_policy: Reading...
# module.cloud_run_web.data.google_iam_policy.cloud_run_policy: Read complete after 0s [id=426047572]
# module.cloud_run_web.google_cloud_run_service.service: Refreshing state... [id=locations/us-central1/namespaces/fs-microservices/services/dev-web-service]
# module.cloud_run_web.google_cloud_run_service_iam_policy.app_service_iam: Refreshing state... [id=v1/projects/fs-microservices/locations/us-central1/services/dev-web-service]
# module.cloud_run_web.google_compute_region_network_endpoint_group.cloudrun_neg: Refreshing state... [id=projects/fs-microservices/regions/us-central1/networkEndpointGroups/dev-web-service-neg]
#
# No changes. Your infrastructure matches the configuration.
#
# Terraform has compared your real infrastructure against your configuration and
# found no differences, so no changes are needed.
# ╷
# │ Warning: Value for undeclared variable
# │
# │ The root module does not declare a variable named "project_name" but a value
# │ was found in file "terraform.tfvars". If you meant to use this value, add a
# │ "variable" block to the configuration.
# │
# │ To silence these warnings, use TF_VAR_... environment variables to provide
# │ certain "global" settings to all configurations in your organization. To
# │ reduce the verbosity of these warnings, use the -compact-warnings option.
# ╵
# ╷
# │ Warning: Value for undeclared variable
# │
# │ The root module does not declare a variable named "bucket_name" but a value
# │ was found in file "terraform.tfvars". If you meant to use this value, add a
# │ "variable" block to the configuration.
# │
# │ To silence these warnings, use TF_VAR_... environment variables to provide
# │ certain "global" settings to all configurations in your organization. To
# │ reduce the verbosity of these warnings, use the -compact-warnings option.
# ╵

# %% [markdown]
# Note: The following command will fail with an error because we haven't uploaded Docker image yet. Ideally you want to comment out all services in the `main.tf` file and when you are finished with all the other notebooks, you can uncomment the services and run terraform apply again.

# %%
# !terraform apply --auto-approve
# Out:
# Acquiring state lock. This may take a few moments...
# module.firebase.google_project_service.firebase_api: Refreshing state... [id=fs-microservices/firebase.googleapis.com]
# module.vpc.google_compute_network.vpc: Refreshing state... [id=projects/fs-microservices/global/networks/dev-vpc]
# module.ci_cd_service_account.google_service_account.ci_cd: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com]
# module.ci_cd_service_account.google_secret_manager_secret.ci_cd_key_secret: Refreshing state... [id=projects/fs-microservices/secrets/dev-gcp-auth-sa-key]
# module.artifact_registry.google_artifact_registry_repository.docker_repository: Refreshing state... [id=projects/fs-microservices/locations/us-central1/repositories/dev-repo]
# module.firebase.google_firebase_web_app.default: Refreshing state... [id=projects/fs-microservices/webApps/1:526101498496:web:66e64ad28b91a63f3f3465]
# module.vpc.google_compute_global_address.private_ip_address: Refreshing state... [id=projects/fs-microservices/global/addresses/dev-private-ip]
# module.vpc.google_compute_subnetwork.subnet: Refreshing state... [id=projects/fs-microservices/regions/us-central1/subnetworks/dev-subnet]
# module.vpc.google_compute_router.router[0]: Refreshing state... [id=projects/fs-microservices/regions/us-central1/routers/dev-router]
# module.vpc.google_compute_firewall.allow_egress: Refreshing state... [id=projects/fs-microservices/global/firewalls/dev-allow-egress]
# module.vpc.google_compute_firewall.allow_internal: Refreshing state... [id=projects/fs-microservices/global/firewalls/dev-allow-internal]
# module.vpc.google_compute_firewall.allow_iap_ssh: Refreshing state... [id=projects/fs-microservices/global/firewalls/dev-allow-iap-ssh]
# module.vpc.google_service_networking_connection.private_vpc_connection["projects/fs-microservices/global/networks/dev-vpc"]: Refreshing state... [id=projects%2Ffs-microservices%2Fglobal%2Fnetworks%2Fdev-vpc:servicenetworking.googleapis.com]
# module.ci_cd_service_account.google_project_iam_member.ci_cd_sa_permissions["roles/cloudsql.client"]: Refreshing state... [id=fs-microservices/roles/cloudsql.client/serviceAccount:dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com]
# module.ci_cd_service_account.google_project_iam_member.ci_cd_sa_permissions["roles/secretmanager.secretAccessor"]: Refreshing state... [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com]
# module.ci_cd_service_account.google_project_iam_member.ci_cd_sa_permissions["roles/editor"]: Refreshing state... [id=fs-microservices/roles/editor/serviceAccount:dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com]
# module.ci_cd_service_account.google_service_account_key.ci_cd_key: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-ci-cd-service-account@fs-microservices.iam.gserviceaccount.com/keys/377e67e60f2f29e5d1d14d7d52fd8226938646a1]
# module.ci_cd_service_account.google_secret_manager_secret_version.ci_cd_key_secret_version: Refreshing state... [id=projects/526101498496/secrets/dev-gcp-auth-sa-key/versions/1]
# module.vpc.google_vpc_access_connector.connector: Refreshing state... [id=projects/fs-microservices/locations/us-central1/connectors/dev-connector]
# module.vpc.google_compute_router_nat.nat[0]: Refreshing state... [id=fs-microservices/us-central1/dev-router/dev-nat]
# module.cloud_sql.data.google_secret_manager_secret_version.db_passwords["auth"]: Reading...
# module.cloud_sql.data.google_secret_manager_secret_version.db_usernames["events"]: Reading...
# module.cloud_sql.data.google_secret_manager_secret_version.db_usernames["auth"]: Reading...
# module.cloud_sql.data.google_secret_manager_secret_version.db_passwords["events"]: Reading...
# module.cloud_sql.data.google_compute_default_service_account.default: Reading...
# module.rabbitmq.google_service_account.rabbitmq_sa: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-rabbitmq-sa@fs-microservices.iam.gserviceaccount.com]
# module.rabbitmq.data.google_compute_default_service_account.default: Reading...
# module.cloud_sql.google_compute_global_address.private_ip_address: Refreshing state... [id=projects/fs-microservices/global/addresses/dev-db-private-ip]
# module.cloud_sql.google_sql_database_instance.postgres_instance: Refreshing state... [id=dev-db-instance]
# module.cloud_run_storybook.google_service_account.cloud_run_sa: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-storybook-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_sql.data.google_secret_manager_secret_version.db_usernames["auth"]: Read complete after 0s [id=projects/526101498496/secrets/dev-auth-db-user/versions/1]
# module.rabbitmq.google_project_iam_member.rabbitmq_sa_permissions["roles/artifactregistry.reader"]: Refreshing state... [id=fs-microservices/roles/artifactregistry.reader/serviceAccount:dev-rabbitmq-sa@fs-microservices.iam.gserviceaccount.com]
# module.rabbitmq.google_project_iam_member.rabbitmq_sa_permissions["roles/logging.logWriter"]: Refreshing state... [id=fs-microservices/roles/logging.logWriter/serviceAccount:dev-rabbitmq-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_sql.data.google_secret_manager_secret_version.db_usernames["events"]: Read complete after 0s [id=projects/526101498496/secrets/dev-events-db-user/versions/1]
# module.rabbitmq.google_project_iam_member.rabbitmq_sa_permissions["roles/monitoring.metricWriter"]: Refreshing state... [id=fs-microservices/roles/monitoring.metricWriter/serviceAccount:dev-rabbitmq-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_sql.data.google_secret_manager_secret_version.db_passwords["auth"]: Read complete after 0s [id=projects/526101498496/secrets/dev-auth-db-password/versions/1]
# module.cloud_sql.data.google_secret_manager_secret_version.db_passwords["events"]: Read complete after 0s [id=projects/526101498496/secrets/dev-events-db-password/versions/1]
# module.cloud_sql.google_sql_database.databases["auth"]: Refreshing state... [id=projects/fs-microservices/instances/dev-db-instance/databases/auth_db]
# module.cloud_sql.google_sql_user.database_users["events"]: Refreshing state... [id=events_user//dev-db-instance]
# module.cloud_sql.google_sql_user.database_users["auth"]: Refreshing state... [id=auth_user//dev-db-instance]
# module.cloud_sql.google_sql_database.databases["events"]: Refreshing state... [id=projects/fs-microservices/instances/dev-db-instance/databases/events_db]
# module.cloud_run_storybook.data.google_iam_policy.cloud_run_policy: Reading...
# module.cloud_run_storybook.data.google_iam_policy.cloud_run_policy: Read complete after 0s [id=739928917]
# module.cloud_run_storybook.google_project_iam_member.cloud_run_sa_secret_manager_permissions: Refreshing state... [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:dev-storybook-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_sql.data.google_compute_default_service_account.default: Read complete after 1s [id=projects/fs-microservices/serviceAccounts/526101498496-compute@developer.gserviceaccount.com]
# module.cloud_sql.google_project_iam_member.default_sa_cloudsql_client_permissions: Refreshing state... [id=fs-microservices/roles/cloudsql.client/serviceAccount:526101498496-compute@developer.gserviceaccount.com]
# module.cloud_sql.google_project_iam_member.default_sa_secret_manager_permissions: Refreshing state... [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:526101498496-compute@developer.gserviceaccount.com]
# module.rabbitmq.data.google_compute_default_service_account.default: Read complete after 1s [id=projects/fs-microservices/serviceAccounts/526101498496-compute@developer.gserviceaccount.com]
# module.rabbitmq.google_project_iam_member.iap_tunnel_user: Refreshing state... [id=fs-microservices/roles/iap.tunnelResourceAccessor/serviceAccount:526101498496-compute@developer.gserviceaccount.com]
# module.rabbitmq.google_compute_instance.rabbitmq: Refreshing state... [id=projects/fs-microservices/zones/us-central1-a/instances/dev-rabbitmq]
# module.cloud_run_storybook.google_cloud_run_service.service: Refreshing state... [id=locations/us-central1/namespaces/fs-microservices/services/dev-storybook-service]
# module.cloud_run_storybook.google_cloud_run_service_iam_policy.app_service_iam: Refreshing state... [id=v1/projects/fs-microservices/locations/us-central1/services/dev-storybook-service]
# module.cloud_run_storybook.google_compute_region_network_endpoint_group.cloudrun_neg: Refreshing state... [id=projects/fs-microservices/regions/us-central1/networkEndpointGroups/dev-storybook-service-neg]
# module.rabbitmq.google_compute_firewall.rabbitmq: Refreshing state... [id=projects/fs-microservices/global/firewalls/dev-rabbitmq-allow]
# module.firebase.google_firebase_project.default: Refreshing state... [id=projects/fs-microservices]
# module.cloud_run_auth.google_service_account.cloud_run_sa: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-auth-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_events.google_service_account.cloud_run_sa: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-events-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_auth.google_project_iam_member.cloud_run_sa_secret_manager_permissions: Refreshing state... [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:dev-auth-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_auth.data.google_iam_policy.cloud_run_policy: Reading...
# module.cloud_run_auth.google_project_iam_member.cloud_run_sa_sql_client_permissions[0]: Refreshing state... [id=fs-microservices/roles/cloudsql.client/serviceAccount:dev-auth-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_auth.data.google_iam_policy.cloud_run_policy: Read complete after 0s [id=580184311]
# module.cloud_run_events.google_project_iam_member.cloud_run_sa_secret_manager_permissions: Refreshing state... [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:dev-events-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_events.google_project_iam_member.cloud_run_sa_sql_client_permissions[0]: Refreshing state... [id=fs-microservices/roles/cloudsql.client/serviceAccount:dev-events-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_events.data.google_iam_policy.cloud_run_policy: Reading...
# module.cloud_run_events.data.google_iam_policy.cloud_run_policy: Read complete after 0s [id=3535090946]
# module.cloud_run_auth.google_cloud_run_service.service: Refreshing state... [id=locations/us-central1/namespaces/fs-microservices/services/dev-auth-service]
# module.cloud_run_auth.google_cloud_run_service_iam_policy.app_service_iam: Refreshing state... [id=v1/projects/fs-microservices/locations/us-central1/services/dev-auth-service]
# module.cloud_run_auth.google_compute_region_network_endpoint_group.cloudrun_neg: Refreshing state... [id=projects/fs-microservices/regions/us-central1/networkEndpointGroups/dev-auth-service-neg]
# module.cloud_run_events.google_cloud_run_service.service: Refreshing state... [id=locations/us-central1/namespaces/fs-microservices/services/dev-events-service]
# module.cloud_run_events.google_cloud_run_service_iam_policy.app_service_iam: Refreshing state... [id=v1/projects/fs-microservices/locations/us-central1/services/dev-events-service]
# module.cloud_run_events.google_compute_region_network_endpoint_group.cloudrun_neg: Refreshing state... [id=projects/fs-microservices/regions/us-central1/networkEndpointGroups/dev-events-service-neg]
# module.cloud_run_gateway.google_service_account.cloud_run_sa: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-gateway-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_gateway.google_project_iam_member.cloud_run_sa_secret_manager_permissions: Refreshing state... [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:dev-gateway-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_gateway.data.google_iam_policy.cloud_run_policy: Reading...
# module.cloud_run_gateway.data.google_iam_policy.cloud_run_policy: Read complete after 0s [id=2670789318]
# module.cloud_run_gateway.google_cloud_run_service.service: Refreshing state... [id=locations/us-central1/namespaces/fs-microservices/services/dev-gateway-service]
# module.cloud_run_gateway.google_cloud_run_service_iam_policy.app_service_iam: Refreshing state... [id=v1/projects/fs-microservices/locations/us-central1/services/dev-gateway-service]
# module.cloud_run_gateway.google_compute_region_network_endpoint_group.cloudrun_neg: Refreshing state... [id=projects/fs-microservices/regions/us-central1/networkEndpointGroups/dev-gateway-service-neg]
# module.cloud_run_web.google_service_account.cloud_run_sa: Refreshing state... [id=projects/fs-microservices/serviceAccounts/dev-web-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_web.google_project_iam_member.cloud_run_sa_secret_manager_permissions: Refreshing state... [id=fs-microservices/roles/secretmanager.secretAccessor/serviceAccount:dev-web-service-sa@fs-microservices.iam.gserviceaccount.com]
# module.cloud_run_web.google_cloud_run_service.service: Refreshing state... [id=locations/us-central1/namespaces/fs-microservices/services/dev-web-service]
# module.cloud_run_web.google_cloud_run_service_iam_policy.app_service_iam: Refreshing state... [id=v1/projects/fs-microservices/locations/us-central1/services/dev-web-service]
# module.cloud_run_web.google_compute_region_network_endpoint_group.cloudrun_neg: Refreshing state... [id=projects/fs-microservices/regions/us-central1/networkEndpointGroups/dev-web-service-neg]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   + create
#   ~ update in-place
#   - destroy
#  <= read (data resources)
#
# Terraform will perform the following actions:
#
#   # module.cloud_run_web.data.google_iam_policy.cloud_run_policy will be read during apply
#   # (depends on a resource or a module with changes pending)
#  <= data "google_iam_policy" "cloud_run_policy" {
#       + id          = (known after apply)
#       + policy_data = (known after apply)
#
#       + binding {
#           + members = [
#               + "allUsers",
#             ]
#           + role    = "roles/run.invoker"
#         }
#       + binding {
#           + members = [
#               + "serviceAccount:dev-web-service-sa@fs-microservices.iam.gserviceaccount.com",
#             ]
#           + role    = "roles/run.admin"
#         }
#     }
#
#   # module.cloud_run_web.google_cloud_run_service.service will be updated in-place
#   ~ resource "google_cloud_run_service" "service" {
#         id                         = "locations/us-central1/namespaces/fs-microservices/services/dev-web-service"
#         name                       = "dev-web-service"
#         # (4 unchanged attributes hidden)
#
#       ~ template {
#           ~ spec {
#                 # (3 unchanged attributes hidden)
#
#               ~ containers {
#                     # (3 unchanged attributes hidden)
#
#                   - env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   - env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   - env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   - env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   - env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#                   + env {
#                       # At least one attribute in this block is (or was) sensitive,
#                       # so its contents will not be displayed.
#                     }
#
#                     # (7 unchanged blocks hidden)
#                 }
#             }
#
#             # (1 unchanged block hidden)
#         }
#
#         # (2 unchanged blocks hidden)
#     }
#
#   # module.cloud_run_web.google_cloud_run_service_iam_policy.app_service_iam will be updated in-place
#   ~ resource "google_cloud_run_service_iam_policy" "app_service_iam" {
#         id          = "v1/projects/fs-microservices/locations/us-central1/services/dev-web-service"
#       ~ policy_data = jsonencode(
#             {
#               - bindings = [
#                   - {
#                       - members = [
#                           - "serviceAccount:dev-web-service-sa@fs-microservices.iam.gserviceaccount.com",
#                         ]
#                       - role    = "roles/run.admin"
#                     },
#                   - {
#                       - members = [
#                           - "allUsers",
#                         ]
#                       - role    = "roles/run.invoker"
#                     },
#                 ]
#             }
#         ) -> (known after apply)
#         # (4 unchanged attributes hidden)
#     }
#
#   # module.firebase.data.google_firebase_web_app_config.env_specific will be read during apply
#   # (config refers to values not yet known)
#  <= data "google_firebase_web_app_config" "env_specific" {
#       + api_key             = (known after apply)
#       + auth_domain         = (known after apply)
#       + database_url        = (known after apply)
#       + id                  = (known after apply)
#       + location_id         = (known after apply)
#       + measurement_id      = (known after apply)
#       + messaging_sender_id = (known after apply)
#       + project             = "fs-microservices"
#       + storage_bucket      = (known after apply)
#       + web_app_id          = (known after apply)
#     }
#
#   # module.firebase.google_firebase_web_app.default will be destroyed
#   # (because google_firebase_web_app.default is not in configuration)
#   - resource "google_firebase_web_app" "default" {
#       - api_key_id      = "d099b91a-095c-4256-b841-3977fd7568ac" -> null
#       - app_id          = "1:526101498496:web:66e64ad28b91a63f3f3465" -> null
#       - app_urls        = [] -> null
#       - deletion_policy = "DELETE" -> null
#       - display_name    = "fs-microservices-dev-web-app" -> null
#       - id              = "projects/fs-microservices/webApps/1:526101498496:web:66e64ad28b91a63f3f3465" -> null
#       - name            = "projects/fs-microservices/webApps/1:526101498496:web:66e64ad28b91a63f3f3465" -> null
#       - project         = "fs-microservices" -> null
#     }
#
#   # module.firebase.google_firebase_web_app.env_specific will be created
#   + resource "google_firebase_web_app" "env_specific" {
#       + api_key_id      = (known after apply)
#       + app_id          = (known after apply)
#       + app_urls        = (known after apply)
#       + deletion_policy = "DELETE"
#       + display_name    = "fs-microservices-dev-web-app"
#       + id              = (known after apply)
#       + name            = (known after apply)
#       + project         = "fs-microservices"
#     }
#
# Plan: 1 to add, 2 to change, 1 to destroy.
# module.firebase.google_firebase_web_app.default: Destroying... [id=projects/fs-microservices/webApps/1:526101498496:web:66e64ad28b91a63f3f3465]
# module.firebase.google_firebase_web_app.env_specific: Creating...
# module.firebase.google_firebase_web_app.default: Destruction complete after 6s
# module.firebase.google_firebase_web_app.env_specific: Still creating... [10s elapsed]
# module.firebase.google_firebase_web_app.env_specific: Creation complete after 12s [id=projects/fs-microservices/webApps/1:526101498496:web:783a17bb109c49413f3465]
# module.firebase.data.google_firebase_web_app_config.env_specific: Reading...
# module.firebase.data.google_firebase_web_app_config.env_specific: Read complete after 1s [id=1:526101498496:web:783a17bb109c49413f3465]
# module.cloud_run_web.data.google_iam_policy.cloud_run_policy: Reading...
# module.cloud_run_web.data.google_iam_policy.cloud_run_policy: Read complete after 0s [id=426047572]
# module.cloud_run_web.google_cloud_run_service.service: Modifying... [id=locations/us-central1/namespaces/fs-microservices/services/dev-web-service]
# module.cloud_run_web.google_cloud_run_service.service: Still modifying... [id=locations/us-central1/namespaces/fs-microservices/services/dev-web-service, 10s elapsed]
# module.cloud_run_web.google_cloud_run_service.service: Modifications complete after 12s [id=locations/us-central1/namespaces/fs-microservices/services/dev-web-service]
# ╷
# │ Warning: Value for undeclared variable
# │
# │ The root module does not declare a variable named "project_name" but a value
# │ was found in file "terraform.tfvars". If you meant to use this value, add a
# │ "variable" block to the configuration.
# │
# │ To silence these warnings, use TF_VAR_... environment variables to provide
# │ certain "global" settings to all configurations in your organization. To
# │ reduce the verbosity of these warnings, use the -compact-warnings option.
# ╵
# ╷
# │ Warning: Value for undeclared variable
# │
# │ The root module does not declare a variable named "bucket_name" but a value
# │ was found in file "terraform.tfvars". If you meant to use this value, add a
# │ "variable" block to the configuration.
# │
# │ To silence these warnings, use TF_VAR_... environment variables to provide
# │ certain "global" settings to all configurations in your organization. To
# │ reduce the verbosity of these warnings, use the -compact-warnings option.
# ╵
#
# Apply complete! Resources: 1 added, 1 changed, 1 destroyed.
